# %%
''' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '''
# Out:
# ' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '

# %% [markdown]
# 1. option to choose file or enter text - done
# 2. if key is 0 or equivalent take a random key - not required
# 3. select random key for encryption itself - done
# 4. file not found break - done
# 5. Issue with \n\r etc
# 6. positional parameters
# 7. brute force
# 8. auto convert to py - done

# %%
import string
from os import path
from random import randint

# %%
DICT = string.printable
DICT_LEN = len(DICT)

# %%
class Encrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be encrypted. '''
        text = str(input('Enter the text to be encrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be encrypted. '''  
        while True:
            file = str(input('''Enter the file with path to be encrypted :  '''))
            try:
                with open(file,'r') as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:
                return f_contents,file
                break
                
    
    @staticmethod
    def get_key(en_key=None):
        
        ### DICT_KEYS are the map of original letters 
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Key needs to be a positive or negative number! : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN   #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            for index,letter in enumerate(DICT):

                new_index = (en_key  + index) % DICT_LEN   # since new_index will go over dict_len , cycle  
                DICT_KEYS[letter] = DICT[new_index]        # Creates dictionary map

        return DICT_KEYS, original_key, en_key                   
    
    
    @staticmethod
    def encrypt_text(text, dict_keys, original_key, new_key):
        
        return ''.join([ dict_keys[letter] for letter in text ]), original_key, new_key

    
    @staticmethod
    def encrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        new_file = path.splitext(file)[0] +  '.cen'
        text = ''.join([ dict_keys[letter] for letter in text ])
        with open(new_file,'w') as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
class Decrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        text = str(input('Enter the text to be Decrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        while True:
            file = str(input('''Enter the file with path to be decrypted :  '''))
            try:
                with open(file,'r') as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:   
                return f_contents,file 
                break
    
    
    @staticmethod
    def get_key():
        
        DICT_KEYS = dict()
        
        ### Input ###
        while True:
            try:
                en_key = int(input('Enter the key. Normal or shortened. : '))
                if type(en_key) == type(float()):
                    raise ValueError
            except ValueError:
                print(f'Key can only be a positive or negative integer number!')
            else:
                break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN      #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            en_key = -(en_key) #Decrypt means , negative key 
            for index,letter in enumerate(DICT):

                #new_index = abs( index - en_key ) % DICT_LEN   # since new_index will go over dict_len , cycle  
                new_index = (en_key  + index) % DICT_LEN
                DICT_KEYS[letter] = DICT[new_index]            # Creates dictionary map

        
        #print(DICT_KEYS)
        return DICT_KEYS, original_key, abs(en_key)                   
    
    
    @staticmethod
    def decrypt_text(text, dict_keys, original_key, new_key):
        
        return ''.join([ dict_keys[letter] for letter in text ]), original_key, new_key
   
    @staticmethod
    def decrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        
        new_file = path.splitext(file)[0] + '.cde'
        text = ''.join([ dict_keys[letter] for letter in text ])
        with open(new_file,'w') as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
def choices():
    
    while True:
        ced = str(input('Encryption or Decryption [E/D] ? : ')).lower() 
        if ced not in {'e','d'}:
            continue
        while True:
            ctf = str(input('Text or File [T/F] ? : ')).lower() 
            if ctf not in {'t','f'}:
                continue
            break
        break
    return ced,ctf

# %%
def key_choice():
    
    while True:
        cyn = str(input('Want to enter a key or select a random key [Y/N] ? :')).lower()
        if cyn not in {'y','n'}:
            continue
    break
    return cyn
# Out:
#   File "<ipython-input-10-f81dd1eaaa0f>", line 10
# SyntaxError: 'break' outside loop

# %%
def main():
    
    ### Welcome ###
    print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
    print('Encryption will take place for ascii characters only.')
    print('Enter either text or file you want to encrypt and a key.')
    print('For multiline input, use the file option.')
    print('Key can be a positive or negative number.')
    print('\nHave fun!!!  ¯\_(^^)_/¯ \n\n')
    
    ### Choices ###
    ced,ctf = choices()
    if ced == 'e':      ### Encrypt ###
        
        e = Encrypt()
        
        if ctf == 't':      ### Text input ###
            text = e.get_text()
            cyn = key_choice()
            
            if cyn == 'y':      ### Key input ###
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
            
            
            result = e.encrypt_text(text, dict_keys, original_key, new_key)      ### Encryption ###
            print('\n\n')
            print(f'''Encrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
        
        
        if ctf == 'f':      ### File input ###
            text,file = e.get_text_from_file()
            cyn = key_choice()
            if cyn == 'y':      ### Key input ### 
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
                
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key)
            
            print('\n\n')
            print(f'''Encrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
                           
    else:
        
        d = Decrypt()

        if ctf == 't':      ### Text input ###
            text = d.get_text()            
            dict_keys, original_key, new_key = d.get_key()
            
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
            
            print('\n\n')
            print(f'''Decrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
            

        if ctf == 'f':      ### File input ###
            text,file = d.get_text_from_file()
            dict_keys, original_key, new_key = d.get_key()
                
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key)
            
            print('\n\n')
            print(f'''Decrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')

# %%
### This is to convert ipynb files to py if run in Jupyter notebook ###
### Also this will cause no problem even if .py file is directly run ###
try :
    terminal = get_ipython().__class__.__name__ 
except Exception:
    pass
else :
    if get_ipython().__class__.__name__ == 'ZMQInteractiveShell':
        # !jupyter nbconvert --to script caesar_cipher.ipynb
        # !pylint caesar_cipher.py
        # !autopep8 --in-place --aggressive caesar_cipher.py
        # !pylint caesar_cipher.py  
finally :
    if __name__ == "__main__" :
        main()
# Out:
# [NbConvertApp] Converting notebook caesar_cipher.ipynb to script
# [NbConvertApp] Writing 10229 bytes to caesar_cipher.py
# ************* Module caesar_cipher
# caesar_cipher.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar_cipher.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:38:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:39:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:40:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:43:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:47:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:48:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:49:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:51:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:52:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:56:30: C0326: Exactly one space required after comma
#                 with open(file,'r') as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:61:33: C0326: Exactly one space required after comma
#                 return f_contents,file
#
#                                  ^ (bad-whitespace)
# caesar_cipher.py:63:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:64:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:67:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:68:53: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:70:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:75:0: C0301: Line too long (107/100) (line-too-long)
# caesar_cipher.py:82:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:84:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:86:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:87:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:88:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cipher.py:88:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cipher.py:89:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:91:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:92:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:92:0: C0301: Line too long (120/100) (line-too-long)
# caesar_cipher.py:93:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar_cipher.py:95:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:95:0: C0301: Line too long (106/100) (line-too-long)
# caesar_cipher.py:98:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:99:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:100:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:103:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:104:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:104:62: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] for letter in text ]), original_key, new_key
#
#                                                               ^ (bad-whitespace)
# caesar_cipher.py:106:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:109:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:111:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:111:62: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] for letter in text ])
#
#                                                               ^ (bad-whitespace)
# caesar_cipher.py:112:26: C0326: Exactly one space required after comma
#         with open(new_file,'w') as f:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:114:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:116:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:118:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:125:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:126:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:127:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:132:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:133:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:134:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:136:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:140:30: C0326: Exactly one space required after comma
#                 with open(file,'r') as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:144:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:145:38: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:145:33: C0326: Exactly one space required after comma
#                 return f_contents,file
#
#                                  ^ (bad-whitespace)
# caesar_cipher.py:147:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:148:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:151:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:153:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:164:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:166:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:168:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:169:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:170:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cipher.py:170:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cipher.py:171:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:173:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:174:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:174:0: C0301: Line too long (123/100) (line-too-long)
# caesar_cipher.py:175:60: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:176:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar_cipher.py:178:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:178:0: C0301: Line too long (111/100) (line-too-long)
# caesar_cipher.py:182:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:184:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:185:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:186:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:189:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:190:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:190:62: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] for letter in text ]), original_key, new_key
#
#                                                               ^ (bad-whitespace)
# caesar_cipher.py:191:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:194:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:195:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:197:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:197:62: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] for letter in text ])
#
#                                                               ^ (bad-whitespace)
# caesar_cipher.py:198:26: C0326: Exactly one space required after comma
#         with open(new_file,'w') as f:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:200:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:208:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:210:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:211:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:214:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:215:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:219:14: C0326: Exactly one space required after comma
#     return ced,ctf
#
#               ^ (bad-whitespace)
# caesar_cipher.py:226:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:229:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:240:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:242:0: C0301: Line too long (117/100) (line-too-long)
# caesar_cipher.py:242:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar_cipher.py:248:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:250:7: C0326: Exactly one space required after comma
#     ced,ctf = choices()
#
#        ^ (bad-whitespace)
# caesar_cipher.py:252:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:254:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:258:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:262:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar_cipher.py:263:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:264:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:268:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:270:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:271:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:273:16: C0326: Exactly one space required after comma
#             text,file = e.get_text_from_file()
#
#                 ^ (bad-whitespace)
# caesar_cipher.py:275:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:278:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar_cipher.py:279:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:281:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:284:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:286:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:288:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:292:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:294:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:296:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:299:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:301:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:304:16: C0326: Exactly one space required after comma
#             text,file = d.get_text_from_file()
#
#                 ^ (bad-whitespace)
# caesar_cipher.py:306:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:308:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:311:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:313:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:321:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar_cipher.py:322:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:325:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar_cipher.py:331:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar_cipher.py:332:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:334:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:341:0: C0305: Trailing newlines (trailing-newlines)
# caesar_cipher.py:247:16: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar_cipher.py:56:39: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:62:16: W0101: Unreachable code (unreachable)
# caesar_cipher.py:66:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:69:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:72:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cipher.py:76:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cipher.py:88:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:102:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:108:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:112:35: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:129:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:135:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:140:39: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:146:16: W0101: Unreachable code (unreachable)
# caesar_cipher.py:150:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:152:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:158:19: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cipher.py:170:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:188:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:193:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:198:35: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:207:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:225:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:229:8: R1724: Unnecessary "else" after "continue" (no-else-continue)
# caesar_cipher.py:239:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:253:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:289:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:239:0: R0915: Too many statements (52/50) (too-many-statements)
# caesar_cipher.py:323:7: W0703: Catching too general exception Exception (broad-except)
# caesar_cipher.py:322:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cipher.py:322:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:326:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:327:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:328:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:329:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:330:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
#
# -------------------------------------------------------------------
#
# Your code has been rated at -1.98/10 (previous run: 6.41/10, -8.38)
# ************* Module caesar_cipher
# caesar_cipher.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar_cipher.py:242:0: C0301: Line too long (116/100) (line-too-long)
# caesar_cipher.py:54:40: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:60:16: W0101: Unreachable code (unreachable)
# caesar_cipher.py:63:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:66:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:86:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:103:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:109:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:113:36: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:127:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:132:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:138:40: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:144:16: W0101: Unreachable code (unreachable)
# caesar_cipher.py:147:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:149:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:167:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:187:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:193:4: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:197:36: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:206:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:224:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:229:8: R1724: Unnecessary "else" after "continue" (no-else-continue)
# caesar_cipher.py:239:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cipher.py:253:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:294:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:239:0: R0915: Too many statements (52/50) (too-many-statements)
# caesar_cipher.py:330:7: W0703: Catching too general exception Exception (broad-except)
# caesar_cipher.py:329:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cipher.py:329:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:333:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:334:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:335:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:336:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:337:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
#
# -------------------------------------------------------------------
#
# Your code has been rated at 6.47/10 (previous run: -1.98/10, +8.44)
#
#
#
# Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher's principle.
# Encryption will take place for ascii characters only.
# Enter either text or file you want to encrypt and a key.
# For multiline input, use the file option.
# Key can be a positive or negative number.
#
# Have fun!!!  ¯\_(^^)_/¯
#
#
# Encryption or Decryption [E/D] ? : e
# Text or File [T/F] ? : t
# Enter the text to be encrypted : jjj
# Want to enter a key or select a random key [Y/N] ? :y
# Enter the key. Key needs to be a positive or negative number! : 7
#
#
#
# Encrypted text : 'qqq'
# Key            : '7'
# Shortened key  : '7'
