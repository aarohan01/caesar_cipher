# %%
''' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '''
# Out:
# ' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '

# %%
import sys
from os import path
from random import randint
import chardet
import argparse

# %%
DICT = [chr(letter) for letter in range(sys.maxunicode)]
DICT_LEN = sys.maxunicode

# %%
### Mashup ###
result = list()
for num in range(0,DICT_LEN,3) :
    result += DICT[num:num+3]
DICT = result

# %%
def detect_encoding(file):
    
    ''' This function is to detect file encoding. '''
    with open(file, "rb") as f:
        rawdata = f.read()
        result = chardet.detect(rawdata)
        charenc = result['encoding']
    return charenc

# %%
class Encrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be encrypted. '''
        text = str(input('Enter the text to be encrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file(file=None):
        
        ''' This function is to get the text from a file that is to be encrypted. '''  
        while True:
            
            if file != None:
                file = path.abspath(file)          # Get absolute path
                if not path.exists(file):
                    print('File not found !!! Try again.')
                    exit()                         # If cmdline path not exist exit
            else:
                file = str(input('''Enter the file with path to be encrypted :  '''))
            
            file = path.abspath(file)          # Get absolute path 
            charenc = detect_encoding(file)    # Detect encoding
    
            try:
                with open(file,'r', encoding=charenc) as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            #except UnicodeDecodeError:
            #    with open(file,'r') as f:
            #        f_contents = f.read()
            #        break
            else:
                break
        
        return f_contents, file, charenc
    
                
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Key needs to be a positive or negative number! : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN   #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            for index,letter in enumerate(DICT):

                new_index = (en_key  + index) % DICT_LEN   # since new_index will go over dict_len , cycle  
                DICT_KEYS[letter] = DICT[new_index]        # Creates dictionary map

        return DICT_KEYS, original_key, en_key                   
    
    
    @staticmethod
    def encrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns encrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key

    
    @staticmethod    
    def encrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc):
        
        ''' This function writes encrypted text to file. '''
        new_file = path.splitext(file)[0] +  '.cen'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        #with open(new_file,'w', encoding="utf-8") as f:
        with open(new_file,'w', encoding=charenc) as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
class Decrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be decrypted. '''
        text = str(input('Enter the text to be Decrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file(file=None):
        
        ''' This function is to get the text from a file that is to be decrypted. ''' 
        while True:
            
            if file != None:
                file = path.abspath(file)          # Get absolute path
                if not path.exists(file):
                    print('File not found !!! Try again.')
                    exit()                         # If cmdline path not exist exit
            else:
                file = str(input('''Enter the file with path to be decrypted :  '''))
            
            file = path.abspath(file)
            charenc = detect_encoding(file) 
            
            try:
                with open(file,'r', encoding=charenc) as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:   
                return f_contents, file, charenc 
                break
    
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Normal or shortened. : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break

        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN      #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            en_key = -(en_key)      #Decrypt means , negative key 
            for index, letter in enumerate(DICT):

                #new_index = abs( index - en_key ) % DICT_LEN   # since new_index will go over dict_len , cycle  
                new_index = (en_key  + index) % DICT_LEN
                DICT_KEYS[letter] = DICT[new_index]            # Creates dictionary map

        
        #print(DICT_KEYS)
        return DICT_KEYS, original_key, abs(en_key)                   
    
    
    @staticmethod
    def decrypt_text(text, dict_keys, original_key, new_key ):
        
        ''' This function returns decrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
   
    @staticmethod
    def decrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc):
        
        ''' This function writes decrypted text to file. '''
        new_file = path.splitext(file)[0] + '.cde'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file, 'w', encoding=charenc) as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
def choices():
    
    ''' This function takes in initial user choices. '''
    while True:
        ced = str(input('Encryption or Decryption ? : [E|D] ')).lower() 
        if ced not in {'e','d'}:
            continue
        while True:
            ctf = str(input('Text or File input ? : [T|F] ')).lower() 
            if ctf not in {'t','f'}:
                continue
            break
        break
    return ced, ctf

# %%
def key_choice():
    
    ''' This function decides whether user wants to enter a key or not. '''
    while True:
        cyn = str(input('Want to enter a key or select a random key? : [Y|N] ')).lower()
        if cyn not in {'y','n'}:
            continue
        break
    return cyn

# %%
def cmdline():

    ''' This function is to accept command line arguments.'''
    parser = argparse.ArgumentParser()
    
    ### Interactive mode ###
    parser.add_argument("-i", "--interactive", dest="i", action="store_true", help="Interactive mode") 

    ### Mutually exclusive group of text and file, since both cannot be together ###
    group_tf = parser.add_mutually_exclusive_group()
    group_tf.add_argument("-t", "--text", dest="t", type=str, help="Text input")
    group_tf.add_argument("-f", "--file-path", dest="f", type=str, help="File input")
    
    ### Mutually exclusive group of encrypt and decrypt, since both cannot be together ###
    group_ed = parser.add_mutually_exclusive_group()
    group_ed.add_argument("-e", "--encypt", dest="e", action="store_true", help="Encrypt") 
    group_ed.add_argument("-d", "--decrypt", dest="d", action="store_true", help="Decrypt") 
    
    ### key parameter ###
    parser.add_argument("-k", "--key", dest="k", type=int, default=False, nargs='?', help="Key") #remember to convert key to int 
    
 
    args = parser.parse_args()
    
    
    ### Interactive mode ###
    if args.i == True or len(sys.argv) <= 1:        # sys.argv is to check number of command line arguments
        return 0
    
    ### T or F condition only ###
    if args.t != None or args.f != None:
        if args.e != True and args.d != True:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.k == False:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
            
            
    ### E or F condition only ###
    if args.e == True or args.d == True:
        if args.t == None and args.f == None:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.k == False:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
    
    ### K condition only ###
    if args.k or not args.k:
        if args.e != True and args.d != True:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.t == None and args.f == None:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        
    return args

# %%
def welcome():
    
    ''' This funtion is to print welcome message. '''
    ### Welcome ###
    print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
    print('Encryption will take place for ascii characters only.')
    print('Enter either text or file you want to encrypt and a key.')
    print('For multiline input, use the file option.')
    print('Key can be a positive or negative number.')
    print('\n')
    print('Have fun!!!  ¯\_(^^)_/¯ ')
    print('\n\n')
    print('''Encryption :\n\tInput -> test.txt\n\tOutput -> test.cen\nDecryption :\n\tInput -> test.cen\n\tOutput -> test.cde''')
    print('''\nUse notepad to open text files encrypted or decrypted.''')

# %%
def print_result(result, action, source):
    
    ''' This function prints the final result output. '''
    print('\n\n')
    print(f'''{action} {source} : '{result[0]}' ''')
    print(f'''Key            : '{result[1]}' ''')  
    print(f'''Shortened key  : '{result[2]}' ''')

# %%
def main_cmd(args):
    
    ''' This is the main function. This controls enverything. '''      
    welcome()
    
    ### Choices ###
    if args.e :      ### Encrypt ###
        
        e = Encrypt()
        
        if args.t != None:      ### Text input ###
            text = args.t
            
            if args.k != None:      ### Key input ###
                dict_keys, original_key, new_key = e.get_key(en_key=args.k)
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
            
            
            result = e.encrypt_text(text, dict_keys, original_key, new_key )      ### Encryption ###
            print_result(result, 'Encrypted', 'text')
        
        
        if args.f != None:      ### File input ###
            text, file, charenc = e.get_text_from_file(args.f)
            
            if args.k != None:      ### Key input ###
                dict_keys, original_key, new_key = e.get_key(en_key=args.k)
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)            
            print_result(result, 'Encrypted', 'file')
                           
    else:
        
        d = Decrypt()

        if args.t != None:      ### Text input ###
            text = args.t    
            if args.k != None:      ### Key input ###
                dict_keys, original_key, new_key = d.get_key(en_key=args.k)
            
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
            print_result(result, 'Decrypted', 'text')
            

        if args.f != None:      ### File input ###
            text, file, charenc = d.get_text_from_file(args.f)
            if args.k != None:
                dict_keys, original_key, new_key = d.get_key(en_key=args.k)
                
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)
            print_result(result, 'Decrypted', 'file')

# %%
def main():
    
    ''' This is the main function. This controls enverything. '''
    welcome()
    
    ### Choices ###
    ced, ctf = choices()
    if ced == 'e':      ### Encrypt ###
        
        e = Encrypt()
        
        if ctf == 't':      ### Text input ###
            text = e.get_text()
            cyn = key_choice()
            
            if cyn == 'y':      ### Key input ###
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
            
            
            result = e.encrypt_text(text, dict_keys, original_key, new_key)      ### Encryption ###
            print_result(result, 'Encrypted', 'text')
        
        
        if ctf == 'f':      ### File input ###
            text, file, charenc = e.get_text_from_file()
            cyn = key_choice()
            if cyn == 'y':      ### Key input ### 
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)
            print_result(result, 'Encrypted', 'file')
                           
    else:
        
        d = Decrypt()

        if ctf == 't':      ### Text input ###
            text = d.get_text()            
            dict_keys, original_key, new_key = d.get_key()
            
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
            print_result(result, 'Decrypted', 'text')
            

        if ctf == 'f':      ### File input ###
            text, file, charenc = d.get_text_from_file()
            dict_keys, original_key, new_key = d.get_key()
                
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)
            print_result(result, 'Decrypted', 'file')

# %%
### This is to convert ipynb files to py if run in Jupyter notebook ###
### Also this will cause no problem even if .py file is directly run ###
try :
    terminal = get_ipython().__class__.__name__ 
except Exception:
    pass
else :
    if get_ipython().__class__.__name__ == 'ZMQInteractiveShell':
        # !jupyter nbconvert --to python caesar.ipynb
        # !pylint caesar.py
        # !autopep8 --in-place --aggressive caesar.py
        # !pylint caesar.py  
finally :
    if __name__ == "__main__" :
        
        ### Get commandline arguments if any ###
        args = cmdline()
        
        ### Interactive or Commandline ###
        if args == 0:
            main()
        else:
            main_cmd(args)
# Out:
# [NbConvertApp] Converting notebook caesar.ipynb to python
# [NbConvertApp] Writing 17907 bytes to caesar.py
# ************* Module caesar
# caesar.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar.py:32:18: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,3) :
#
#                   ^ (bad-whitespace)
# caesar.py:32:27: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,3) :
#
#                            ^ (bad-whitespace)
# caesar.py:32:31: C0326: No space allowed before :
# for num in range(0,DICT_LEN,3) :
#
#                                ^ (bad-whitespace)
# caesar.py:41:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:54:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:55:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:56:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:59:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:63:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:64:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:65:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:67:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:68:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:70:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:78:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:79:66: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:81:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:83:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar.py:93:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:95:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:96:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:97:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:100:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:104:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:109:0: C0301: Line too long (107/100) (line-too-long)
# caesar.py:116:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:118:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:120:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:121:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:122:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:122:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:123:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:125:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:126:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:126:0: C0301: Line too long (120/100) (line-too-long)
# caesar.py:127:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar.py:129:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:129:0: C0301: Line too long (106/100) (line-too-long)
# caesar.py:132:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:133:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:134:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:137:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:140:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:140:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:140:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:142:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:143:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:145:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:149:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:149:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:151:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding=charenc) as f:
#
#                           ^ (bad-whitespace)
# caesar.py:153:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:155:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:157:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:164:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:165:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:166:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:169:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:173:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:174:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:175:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:177:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:178:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:180:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:188:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:190:43: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:191:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:193:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar.py:197:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:198:48: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:200:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:201:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:204:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:208:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:221:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:223:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:225:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:226:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:227:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:227:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:228:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:230:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:231:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:231:0: C0301: Line too long (123/100) (line-too-long)
# caesar.py:232:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:235:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:235:0: C0301: Line too long (111/100) (line-too-long)
# caesar.py:239:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:241:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:242:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:243:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:245:60: C0326: No space allowed before bracket
#     def decrypt_text(text, dict_keys, original_key, new_key ):
#
#                                                             ^ (bad-whitespace)
# caesar.py:246:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:249:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:249:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:249:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:250:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:253:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:257:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:257:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:260:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:268:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:271:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:272:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar.py:275:69: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:276:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar.py:287:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:291:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar.py:304:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:306:102: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:306:0: C0301: Line too long (102/100) (line-too-long)
# caesar.py:312:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:315:90: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:316:91: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:317:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:319:128: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:319:0: C0301: Line too long (128/100) (line-too-long)
# caesar.py:320:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:321:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:323:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:324:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:326:0: C0301: Line too long (107/100) (line-too-long)
# caesar.py:328:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:337:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:338:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:347:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:356:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:358:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:365:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:368:0: C0301: Line too long (117/100) (line-too-long)
# caesar.py:368:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar.py:376:0: C0301: Line too long (129/100) (line-too-long)
# caesar.py:378:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:385:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:389:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:397:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:398:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:400:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:402:14: C0326: No space allowed before :
#     if args.e :      ### Encrypt ###
#
#               ^ (bad-whitespace)
# caesar.py:403:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:405:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:408:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:412:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:413:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:414:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:415:75: C0326: No space allowed before bracket
#             result = e.encrypt_text(text, dict_keys, original_key, new_key )      ### Encryption ###
#
#                                                                            ^ (bad-whitespace)
# caesar.py:417:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:418:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:421:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:425:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:426:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:427:98: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:429:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:431:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:435:25: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:438:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:441:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:447:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:451:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:458:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:461:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:465:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:467:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:471:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:475:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:476:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:477:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:480:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:481:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:485:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:488:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:489:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:492:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:494:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:498:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:500:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:503:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:508:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:518:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar.py:519:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:522:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar.py:528:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar.py:529:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar.py:530:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:533:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:539:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:552:0: C0305: Trailing newlines (trailing-newlines)
# caesar.py:374:14: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar.py:31:0: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:45:8: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:43:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:71:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:75:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:83:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:103:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:106:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:110:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:122:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:144:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:151:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:181:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:185:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:193:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:199:16: W0101: Unreachable code (unreachable)
# caesar.py:207:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:210:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:214:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:227:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:252:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:258:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:322:4: W0621: Redefining name 'args' from outer scope (line 532) (redefined-outer-name)
# caesar.py:326:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:330:7: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:330:25: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:331:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:331:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:334:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:340:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:340:25: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:341:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:341:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:344:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:350:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:350:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:353:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:353:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:384:17: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:396:13: W0621: Redefining name 'args' from outer scope (line 532) (redefined-outer-name)
# caesar.py:415:12: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:404:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:406:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:409:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:419:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:422:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:432:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:434:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:436:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:443:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:445:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:478:12: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:466:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:495:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:520:7: W0703: Catching too general exception Exception (broad-except)
# caesar.py:519:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:519:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:523:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:524:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:525:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:526:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:527:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:532:8: C0103: Constant name "args" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:17:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
#
# -------------------------------------------------------------------
#
# Your code has been rated at -0.57/10 (previous run: 7.21/10, -7.79)
# ************* Module caesar
# caesar.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar.py:139:0: C0301: Line too long (109/100) (line-too-long)
# caesar.py:245:0: C0301: Line too long (109/100) (line-too-long)
# caesar.py:400:0: C0301: Line too long (116/100) (line-too-long)
# caesar.py:408:0: C0301: Line too long (129/100) (line-too-long)
# caesar.py:31:0: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:44:8: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:42:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:71:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:80:58: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:97:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:117:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:142:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:151:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:179:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:188:58: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:194:16: W0101: Unreachable code (unreachable)
# caesar.py:200:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:220:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:248:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:256:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:351:4: W0621: Redefining name 'args' from outer scope (line 576) (redefined-outer-name)
# caesar.py:354:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:360:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:360:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:364:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:370:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:370:25: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:375:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:382:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:382:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:415:17: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:426:13: W0621: Redefining name 'args' from outer scope (line 576) (redefined-outer-name)
# caesar.py:444:12: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:433:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:466:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:513:12: W0621: Redefining name 'result' from outer scope (line 31) (redefined-outer-name)
# caesar.py:501:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:535:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:564:7: W0703: Catching too general exception Exception (broad-except)
# caesar.py:563:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:563:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:567:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:568:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:569:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:570:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:571:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:576:8: C0103: Constant name "args" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:17:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
#
# -------------------------------------------------------------------
#
# Your code has been rated at 7.21/10 (previous run: -0.57/10, +7.79)
# usage: ipykernel_launcher.py [-h] [-i] [-t T | -f F] [-e | -d] [-k [K]]
# ipykernel_launcher.py: error: usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
