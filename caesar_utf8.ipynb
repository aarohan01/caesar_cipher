# %%
''' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '''
# Out:
# ' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '

# %% [markdown]
# 1. option to choose file or enter text - done
# 2. if key is 0 or equivalent take a random key - not required
# 3. select random key for encryption itself - done
# 4. file not found break - done
# 5. Issue with \n\r etc - done
# 6. positional parameters
# 7. brute force
# 8. auto convert to py - done
# 9. if letter not found return same letter - done
# 10. Unicode support - done

# %%
import string
import sys
from os import path
from random import randint

# %%
#DICT = string.printable
DICT = [chr(letter) for letter in range(sys.maxunicode)]
### MASHUP ###
DICT = DICT[::3] + DICT[1::3] + DICT[2::3] 
DICT_LEN = sys.maxunicode

# %%
class Encrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be encrypted. '''
        text = str(input('Enter the text to be encrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be encrypted. '''  
        while True:
            file = str(input('''Enter the file with path to be encrypted :  '''))
            file = path.abspath(file)
            try:
                with open(file,'r', encoding="utf-8") as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            except UnicodeDecodeError:
                with open(file,'r') as f:
                    f_contents = f.read()
                    break
            else:
                break
        
        return f_contents, file
    
                
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Key needs to be a positive or negative number! : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN   #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            for index,letter in enumerate(DICT):

                new_index = (en_key  + index) % DICT_LEN   # since new_index will go over dict_len , cycle  
                DICT_KEYS[letter] = DICT[new_index]        # Creates dictionary map

        return DICT_KEYS, original_key, en_key                   
    
    
    @staticmethod
    def encrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns encrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key

    
    @staticmethod
    def encrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes encrypted text to file. '''
        new_file = path.splitext(file)[0] +  '.cen'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file,'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
class Decrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be decrypted. '''
        text = str(input('Enter the text to be Decrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be decrypted. ''' 
        while True:
            file = str(input('''Enter the file with path to be decrypted :  '''))
            file = path.abspath(file)
            try:
                with open(file,'r', encoding="utf-8") as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:   
                return f_contents, file 
                break
    
    
    @staticmethod
    def get_key():
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        while True:
            try:
                en_key = int(input('Enter the key. Normal or shortened. : '))
                if type(en_key) == type(float()):
                    raise ValueError
            except ValueError:
                print(f'Key can only be a positive or negative integer number!')
            else:
                break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN      #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            en_key = -(en_key)      #Decrypt means , negative key 
            for index, letter in enumerate(DICT):

                #new_index = abs( index - en_key ) % DICT_LEN   # since new_index will go over dict_len , cycle  
                new_index = (en_key  + index) % DICT_LEN
                DICT_KEYS[letter] = DICT[new_index]            # Creates dictionary map

        
        #print(DICT_KEYS)
        return DICT_KEYS, original_key, abs(en_key)                   
    
    
    @staticmethod
    def decrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns decrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
   
    @staticmethod
    def decrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes decrypted text to file. '''
        new_file = path.splitext(file)[0] + '.cde'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file, 'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
def choices():
    
    ''' This function takes in initial user choices. '''
    while True:
        ced = str(input('Encryption or Decryption [E/D] ? : ')).lower() 
        if ced not in {'e','d'}:
            continue
        while True:
            ctf = str(input('Text or File [T/F] ? : ')).lower() 
            if ctf not in {'t','f'}:
                continue
            break
        break
    return ced, ctf

# %%
def key_choice():
    
    ''' This function decides whether user wants to enter a key or not. '''
    while True:
        cyn = str(input('Want to enter a key or select a random key [Y/N] ? :')).lower()
        if cyn not in {'y','n'}:
            continue
        break
    return cyn

# %%
def main():
    
    ''' This is the main function. This controls enverything. '''
    ### Welcome ###
    print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
    print('Encryption will take place for ascii characters only.')
    print('Enter either text or file you want to encrypt and a key.')
    print('For multiline input, use the file option.')
    print('Key can be a positive or negative number.')
    print('\nHave fun!!!  ¯\_(^^)_/¯ \n\n')
    
    ### Choices ###
    ced, ctf = choices()
    if ced == 'e':      ### Encrypt ###
        
        e = Encrypt()
        
        if ctf == 't':      ### Text input ###
            text = e.get_text()
            cyn = key_choice()
            
            if cyn == 'y':      ### Key input ###
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
            
            
            result = e.encrypt_text(text, dict_keys, original_key, new_key)      ### Encryption ###
            print('\n\n')
            print(f'''Encrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
        
        
        if ctf == 'f':      ### File input ###
            text, file = e.get_text_from_file()
            cyn = key_choice()
            if cyn == 'y':      ### Key input ### 
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key)
            
            print('\n\n')
            print(f'''Encrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
                           
    else:
        
        d = Decrypt()

        if ctf == 't':      ### Text input ###
            text = d.get_text()            
            dict_keys, original_key, new_key = d.get_key()
            
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
            
            print('\n\n')
            print(f'''Decrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
            

        if ctf == 'f':      ### File input ###
            text, file = d.get_text_from_file()
            dict_keys, original_key, new_key = d.get_key()
                
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key)
            
            print('\n\n')
            print(f'''Decrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')

# %%
### This is to convert ipynb files to py if run in Jupyter notebook ###
### Also this will cause no problem even if .py file is directly run ###
try :
    terminal = get_ipython().__class__.__name__ 
except Exception:
    pass
else :
    if get_ipython().__class__.__name__ == 'ZMQInteractiveShell':
        # !jupyter nbconvert --to script caesar_cipher.ipynb
        # !pylint caesar_cipher.py
        # !autopep8 --in-place --aggressive caesar_cipher.py
        # !pylint caesar_cipher.py  
finally :
    if __name__ == "__main__" :
        main()
# Out:
# [NbConvertApp] Converting notebook caesar_cipher.ipynb to script
# [NbConvertApp] Writing 12072 bytes to caesar_cipher.py
# ************* Module caesar_cipher
# caesar_cipher.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar_cipher.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:18:50: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:19:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:44:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:45:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:46:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:49:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:53:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:54:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:55:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:57:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:58:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:63:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:68:30: C0326: Exactly one space required after comma
#                 with open(file,'r') as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:73:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:75:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:76:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:77:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:80:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:84:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:89:0: C0301: Line too long (107/100) (line-too-long)
# caesar_cipher.py:96:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:98:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:100:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:101:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:102:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cipher.py:102:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cipher.py:103:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:105:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:106:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:106:0: C0301: Line too long (120/100) (line-too-long)
# caesar_cipher.py:107:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar_cipher.py:109:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:109:0: C0301: Line too long (106/100) (line-too-long)
# caesar_cipher.py:112:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:113:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:114:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:117:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:120:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cipher.py:120:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:120:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:122:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:125:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:129:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:129:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:130:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding="utf-8") as f:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:132:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:134:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:136:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:143:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:144:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:145:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:148:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:152:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:153:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:154:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:156:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:157:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:162:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:166:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:167:39: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:169:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:170:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:173:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:177:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:188:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:190:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:192:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:193:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:194:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cipher.py:194:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cipher.py:195:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:197:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:198:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:198:0: C0301: Line too long (123/100) (line-too-long)
# caesar_cipher.py:199:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:202:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:202:0: C0301: Line too long (111/100) (line-too-long)
# caesar_cipher.py:206:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:208:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:209:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:210:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:213:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:216:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cipher.py:216:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:216:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:217:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:220:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:224:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:224:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:227:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:235:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:238:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:239:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:242:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:243:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:254:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:258:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:268:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:271:0: C0301: Line too long (117/100) (line-too-long)
# caesar_cipher.py:271:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar_cipher.py:277:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:281:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:283:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:287:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:291:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar_cipher.py:292:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:293:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:297:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:299:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:300:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:304:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:307:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar_cipher.py:308:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:310:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:313:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:315:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:317:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:321:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:323:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:325:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:328:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:330:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:335:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:337:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:340:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:342:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:350:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar_cipher.py:351:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:354:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar_cipher.py:360:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar_cipher.py:361:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:363:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:376:0: C0305: Trailing newlines (trailing-newlines)
# caesar_cipher.py:276:16: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar_cipher.py:63:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:68:39: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:83:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:86:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cipher.py:90:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cipher.py:102:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:130:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:162:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:168:16: W0101: Unreachable code (unreachable)
# caesar_cipher.py:176:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:182:19: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cipher.py:194:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:225:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:282:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:318:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:267:0: R0915: Too many statements (52/50) (too-many-statements)
# caesar_cipher.py:352:7: W0703: Catching too general exception Exception (broad-except)
# caesar_cipher.py:351:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cipher.py:351:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:355:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:356:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:357:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:358:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:359:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:24:0: W0611: Unused import string (unused-import)
#
# --------------------------------------------------------------------
#
# Your code has been rated at -0.74/10 (previous run: -0.80/10, +0.06)
# c:\users\tcs1128747\appdata\local\continuum\anaconda3\lib\site-packages\pep8.py:110: FutureWarning: Possible nested set at position 1
#   EXTRANEOUS_WHITESPACE_REGEX = re.compile(r'[[({] | []}),;:]')
# Usage: autopep8 [options] [filename [filename ...]]
#
# autopep8: error: no such option: --aggressive
# ************* Module caesar_cipher
# caesar_cipher.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar_cipher.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:18:50: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:19:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:44:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:45:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:46:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:49:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:53:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:54:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:55:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:57:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:58:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:63:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:68:30: C0326: Exactly one space required after comma
#                 with open(file,'r') as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:73:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:75:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:76:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:77:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:80:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:84:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:89:0: C0301: Line too long (107/100) (line-too-long)
# caesar_cipher.py:96:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:98:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:100:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:101:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:102:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cipher.py:102:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cipher.py:103:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:105:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:106:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:106:0: C0301: Line too long (120/100) (line-too-long)
# caesar_cipher.py:107:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar_cipher.py:109:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:109:0: C0301: Line too long (106/100) (line-too-long)
# caesar_cipher.py:112:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:113:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:114:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:117:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:120:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cipher.py:120:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:120:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:122:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:125:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:129:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:129:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:130:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding="utf-8") as f:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:132:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:134:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:136:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:143:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:144:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:145:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:148:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:152:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:153:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:154:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:156:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:157:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:162:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:166:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:167:39: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:169:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:170:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:173:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:177:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:188:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:190:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:192:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:193:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:194:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cipher.py:194:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cipher.py:195:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:197:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:198:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:198:0: C0301: Line too long (123/100) (line-too-long)
# caesar_cipher.py:199:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:202:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:202:0: C0301: Line too long (111/100) (line-too-long)
# caesar_cipher.py:206:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:208:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:209:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:210:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:213:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:216:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cipher.py:216:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:216:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:217:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:220:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:224:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cipher.py:224:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cipher.py:227:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:235:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:238:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:239:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:242:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:243:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:254:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:258:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar_cipher.py:268:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:271:0: C0301: Line too long (117/100) (line-too-long)
# caesar_cipher.py:271:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar_cipher.py:277:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:281:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:283:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:287:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:291:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar_cipher.py:292:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:293:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:297:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:299:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:300:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:304:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:307:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar_cipher.py:308:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:310:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:313:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:315:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:317:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:321:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:323:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:325:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:328:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:330:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:335:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:337:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:340:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:342:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:350:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar_cipher.py:351:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:354:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar_cipher.py:360:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar_cipher.py:361:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar_cipher.py:363:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cipher.py:376:0: C0305: Trailing newlines (trailing-newlines)
# caesar_cipher.py:276:16: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar_cipher.py:63:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:68:39: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:83:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:86:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cipher.py:90:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cipher.py:102:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:130:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:162:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:168:16: W0101: Unreachable code (unreachable)
# caesar_cipher.py:176:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:182:19: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cipher.py:194:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:225:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:282:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:318:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar_cipher.py:267:0: R0915: Too many statements (52/50) (too-many-statements)
# caesar_cipher.py:352:7: W0703: Catching too general exception Exception (broad-except)
# caesar_cipher.py:351:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cipher.py:351:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:355:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:356:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:357:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:358:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:359:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cipher.py:24:0: W0611: Unused import string (unused-import)
#
# --------------------------------------------------------------------
#
# Your code has been rated at -0.74/10 (previous run: -0.74/10, +0.00)
#
#
#
# Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher's principle.
# Encryption will take place for ascii characters only.
# Enter either text or file you want to encrypt and a key.
# For multiline input, use the file option.
# Key can be a positive or negative number.
#
# Have fun!!!  ¯\_(^^)_/¯
# Encryption or Decryption [E/D] ? : e
# Text or File [T/F] ? : t
# Enter the text to be encrypted : hhhhh
# Want to enter a key or select a random key [Y/N] ? :n
#
#
#
# Encrypted text : '씡씡씡씡씡'
# Key            : '16787'
# Shortened key  : '16787'
