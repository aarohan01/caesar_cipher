# %%
''' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '''
# Out:
# ' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '

# %% [markdown]
# 1. option to choose file or enter text - done
# 2. if key is 0 or equivalent take a random key - not required
# 3. select random key for encryption itself - done
# 4. file not found break - done
# 5. Issue with \n\r etc - done
# 6. positional parameters
# 7. brute force
# 8. auto convert to py - done
# 9. if letter not found return same letter - done
# 10. Unicode support - done
# 11. command line arguments
# 12. better file memory management
# 13. Improved questions
# 14. improved file names saved
# 15. save key in a file
# 16. make a exe

# %%
import sys
from os import path
from random import randint
import chardet
import argparse

# %%
DICT = [chr(letter) for letter in range(sys.maxunicode)]
DICT_LEN = sys.maxunicode

# %%
### Mashup ###
result = list()
for num in range(0,DICT_LEN,3) :
    result += DICT[num:num+3]
DICT = result

# %%
def detect_encoding(file):
    
    ''' This function is to detect file encoding. '''
    with open(file, "rb") as f:
        rawdata = f.read()
        result = chardet.detect(rawdata)
        charenc = result['encoding']
    return charenc

# %%
class Encrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be encrypted. '''
        text = str(input('Enter the text to be encrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file(file=None):
        
        ''' This function is to get the text from a file that is to be encrypted. '''  
        while True:
            
            if file != None:
                file = path.abspath(file)          # Get absolute path
                if not path.exists(file):
                    print('File not found !!! Try again.')
                    exit()                         # If cmdline path not exist exit
            else:
                file = str(input('''Enter the file with path to be encrypted :  '''))
            
            file = path.abspath(file)          # Get absolute path 
            charenc = detect_encoding(file)    # Detect encoding
    
            try:
                with open(file,'r', encoding=charenc) as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            #except UnicodeDecodeError:
            #    with open(file,'r') as f:
            #        f_contents = f.read()
            #        break
            else:
                break
        
        return f_contents, file, charenc
    
                
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Key needs to be a positive or negative number! : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN   #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            for index,letter in enumerate(DICT):

                new_index = (en_key  + index) % DICT_LEN   # since new_index will go over dict_len , cycle  
                DICT_KEYS[letter] = DICT[new_index]        # Creates dictionary map

        return DICT_KEYS, original_key, en_key                   
    
    
    @staticmethod
    def encrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns encrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key

    
    @staticmethod    
    def encrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc):
        
        ''' This function writes encrypted text to file. '''
        new_file = path.splitext(file)[0] +  '.cen'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        #with open(new_file,'w', encoding="utf-8") as f:
        with open(new_file,'w', encoding=charenc) as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
class Decrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be decrypted. '''
        text = str(input('Enter the text to be Decrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file(file=None):
        
        ''' This function is to get the text from a file that is to be decrypted. ''' 
        while True:
            
            if file != None:
                file = path.abspath(file)          # Get absolute path
                if not path.exists(file):
                    print('File not found !!! Try again.')
                    exit()                         # If cmdline path not exist exit
            else:
                file = str(input('''Enter the file with path to be decrypted :  '''))
            
            file = path.abspath(file)
            charenc = detect_encoding(file) 
            
            try:
                with open(file,'r', encoding=charenc) as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:   
                return f_contents, file, charenc 
                break
    
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Normal or shortened. : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break

        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN      #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            en_key = -(en_key)      #Decrypt means , negative key 
            for index, letter in enumerate(DICT):

                #new_index = abs( index - en_key ) % DICT_LEN   # since new_index will go over dict_len , cycle  
                new_index = (en_key  + index) % DICT_LEN
                DICT_KEYS[letter] = DICT[new_index]            # Creates dictionary map

        
        #print(DICT_KEYS)
        return DICT_KEYS, original_key, abs(en_key)                   
    
    
    @staticmethod
    def decrypt_text(text, dict_keys, original_key, new_key, charenc):
        
        ''' This function returns decrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
   
    @staticmethod
    def decrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc):
        
        ''' This function writes decrypted text to file. '''
        new_file = path.splitext(file)[0] + '.cde'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file, 'w', encoding=charenc) as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
def choices():
    
    ''' This function takes in initial user choices. '''
    while True:
        ced = str(input('Encryption or Decryption ? : [E|D] ')).lower() 
        if ced not in {'e','d'}:
            continue
        while True:
            ctf = str(input('Text or File input ? : [T|F] ')).lower() 
            if ctf not in {'t','f'}:
                continue
            break
        break
    return ced, ctf

# %%
def key_choice():
    
    ''' This function decides whether user wants to enter a key or not. '''
    while True:
        cyn = str(input('Want to enter a key or select a random key? : [Y|N] ')).lower()
        if cyn not in {'y','n'}:
            continue
        break
    return cyn

# %%
def cmdline():

    ''' This function is to accept command line arguments.'''
    parser = argparse.ArgumentParser()
    
    ### Interactive mode ###
    parser.add_argument("-i", "--interactive", dest="i", action="store_true", help="Interactive mode") 

    ### Mutually exclusive group of text and file, since both cannot be together ###
    group_tf = parser.add_mutually_exclusive_group()
    group_tf.add_argument("-t", "--text", dest="t", type=str, help="Text input")
    group_tf.add_argument("-f", "--file-path", dest="f", type=str, help="File input")
    
    ### Mutually exclusive group of encrypt and decrypt, since both cannot be together ###
    group_ed = parser.add_mutually_exclusive_group()
    group_ed.add_argument("-e", "--encypt", dest="e", action="store_true", help="Encrypt") 
    group_ed.add_argument("-d", "--decrypt", dest="d", action="store_true", help="Decrypt") 
    
    ### key parameter ###
    parser.add_argument("-k", "--key", dest="k", type=int, default=False, nargs='?', help="Key") #remember to convert key to int 
    
 
    args = parser.parse_args()
    
    
    ### Interactive mode ###
    if args.i == True or len(sys.argv) <= 1:        # sys.argv is to check number of command line arguments
        return 0
    
    ### T or F condition only ###
    if args.t != None or args.f != None:
        if args.e != True and args.d != True:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.k == False:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
            
            
    ### E or F condition only ###
    if args.e == True or args.d == True:
        if args.t == None and args.f == None:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.k == False:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
    
    ### K condition only ###
    if args.k or not args.k:
        if args.e != True and args.d != True:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.t == None and args.f == None:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        
    return args

# %%
def welcome():
    
    ''' This funtion is to print welcome message. '''
    ### Welcome ###
    print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
    print('Encryption will take place for ascii characters only.')
    print('Enter either text or file you want to encrypt and a key.')
    print('For multiline input, use the file option.')
    print('Key can be a positive or negative number.')
    print('\n')
    print('Have fun!!!  ¯\_(^^)_/¯ ')
    print('\n\n')
    print('''Encryption :\n\tInput -> test.txt\n\tOutput -> test.cen\nDecryption :\n\tInput -> test.cen\n\tOutput -> test.cde''')
    print('''\nUse notepad to open text files encrypted or decrypted.''')

# %%
def main_cmd(args):
    
    ''' This is the main function. This controls enverything. '''      
    welcome()
    
    ### Choices ###
    if args.e :      ### Encrypt ###
        
        e = Encrypt()
        
        if args.t != None:      ### Text input ###
            text = args.t
            
            if args.k != None:      ### Key input ###
                dict_keys, original_key, new_key = e.get_key(en_key=args.k)
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
            
            
            result = e.encrypt_text(text, dict_keys, original_key, new_key )      ### Encryption ###
            print('\n\n')
            print(f'''Encrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
        
        
        if args.f != None:      ### File input ###
            text, file, charenc = e.get_text_from_file(args.f)
            
            if args.k != None:      ### Key input ###
                dict_keys, original_key, new_key = e.get_key(en_key=args.k)
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)            
            print('\n\n')
            print(f'''Encrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
                           
    else:
        
        d = Decrypt()

        if args.t != None:      ### Text input ###
            text = args.t    
            if args.k != None:      ### Key input ###
                dict_keys, original_key, new_key = d.get_key(en_key=args.k)
            
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
            
            print('\n\n')
            print(f'''Decrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
            

        if args.f != None:      ### File input ###
            text, file, charenc = d.get_text_from_file(args.f)
            if args.k != None:
                dict_keys, original_key, new_key = d.get_key(en_key=args.k)
                
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)
            
            print('\n\n')
            print(f'''Decrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')

# %%
def main():
    
    ''' This is the main function. This controls enverything. '''
    welcome()
    
    ### Choices ###
    ced, ctf = choices()
    if ced == 'e':      ### Encrypt ###
        
        e = Encrypt()
        
        if ctf == 't':      ### Text input ###
            text = e.get_text()
            cyn = key_choice()
            
            if cyn == 'y':      ### Key input ###
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
            
            
            result = e.encrypt_text(text, dict_keys, original_key, new_key)      ### Encryption ###
            print('\n\n')
            print(f'''Encrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
        
        
        if ctf == 'f':      ### File input ###
            text, file, charenc = e.get_text_from_file()
            cyn = key_choice()
            if cyn == 'y':      ### Key input ### 
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)
            
            print('\n\n')
            print(f'''Encrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
                           
    else:
        
        d = Decrypt()

        if ctf == 't':      ### Text input ###
            text = d.get_text()            
            dict_keys, original_key, new_key = d.get_key()
            
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
            
            print('\n\n')
            print(f'''Decrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
            

        if ctf == 'f':      ### File input ###
            text, file, charenc = d.get_text_from_file()
            dict_keys, original_key, new_key = d.get_key()
                
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key, charenc)
            
            print('\n\n')
            print(f'''Decrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')

# %%
### This is to convert ipynb files to py if run in Jupyter notebook ###
### Also this will cause no problem even if .py file is directly run ###
try :
    terminal = get_ipython().__class__.__name__ 
except Exception:
    pass
else :
    if get_ipython().__class__.__name__ == 'ZMQInteractiveShell':
        # !jupyter nbconvert --to python caesar.ipynb
        # !pylint caesar.py
        # !autopep8 --in-place --aggressive caesar.py
        # !pylint caesar.py  
finally :
    if __name__ == "__main__" :
        
        ### Get commandline arguments if any ###
        args = cmdline()
        
        ### Interactive or Commandline ###
        if args == 0:
            main()
        else:
            main_cmd(args)
# Out:
# [NbConvertApp] Converting notebook caesar.ipynb to python
# [NbConvertApp] Writing 19429 bytes to caesar.py
# ************* Module caesar
# caesar.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:18:50: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:19:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:20:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:24:24: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:49:18: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,3) :
#
#                   ^ (bad-whitespace)
# caesar.py:49:27: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,3) :
#
#                            ^ (bad-whitespace)
# caesar.py:49:31: C0326: No space allowed before :
# for num in range(0,DICT_LEN,3) :
#
#                                ^ (bad-whitespace)
# caesar.py:58:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:71:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:72:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:73:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:76:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:80:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:81:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:82:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:84:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:85:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:87:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:95:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:96:66: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:98:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:100:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar.py:110:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:112:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:113:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:114:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:117:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:121:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:126:0: C0301: Line too long (107/100) (line-too-long)
# caesar.py:133:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:135:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:137:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:138:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:139:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:139:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:140:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:142:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:143:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:143:0: C0301: Line too long (120/100) (line-too-long)
# caesar.py:144:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar.py:146:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:146:0: C0301: Line too long (106/100) (line-too-long)
# caesar.py:149:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:150:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:151:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:154:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:157:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:157:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:157:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:159:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:160:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:162:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:166:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:166:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:168:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding=charenc) as f:
#
#                           ^ (bad-whitespace)
# caesar.py:170:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:172:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:174:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:181:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:182:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:183:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:186:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:190:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:191:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:192:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:194:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:195:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:197:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:205:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:207:43: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:208:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:210:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar.py:214:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:215:48: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:217:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:218:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:221:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:225:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:238:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:240:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:242:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:243:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:244:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:244:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:245:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:247:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:248:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:248:0: C0301: Line too long (123/100) (line-too-long)
# caesar.py:249:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:252:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:252:0: C0301: Line too long (111/100) (line-too-long)
# caesar.py:256:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:258:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:259:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:260:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:263:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:266:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:266:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:266:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:267:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:270:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:274:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:274:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:277:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:285:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:288:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:289:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar.py:292:69: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:293:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar.py:304:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:308:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar.py:321:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:323:102: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:323:0: C0301: Line too long (102/100) (line-too-long)
# caesar.py:329:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:332:90: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:333:91: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:334:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:336:128: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:336:0: C0301: Line too long (128/100) (line-too-long)
# caesar.py:337:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:338:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:340:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:341:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:343:0: C0301: Line too long (107/100) (line-too-long)
# caesar.py:345:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:354:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:355:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:364:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:373:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:375:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:382:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:385:0: C0301: Line too long (117/100) (line-too-long)
# caesar.py:385:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar.py:393:0: C0301: Line too long (129/100) (line-too-long)
# caesar.py:395:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:402:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:403:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:405:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:407:14: C0326: No space allowed before :
#     if args.e :      ### Encrypt ###
#
#               ^ (bad-whitespace)
# caesar.py:408:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:410:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:413:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:417:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:418:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:419:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:420:75: C0326: No space allowed before bracket
#             result = e.encrypt_text(text, dict_keys, original_key, new_key )      ### Encryption ###
#
#                                                                            ^ (bad-whitespace)
# caesar.py:423:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:425:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:426:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:429:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:433:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:434:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:435:98: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:438:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:440:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:442:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:446:25: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:449:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:451:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:454:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:456:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:462:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:464:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:467:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:470:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:477:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:480:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:484:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:486:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:490:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:494:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:495:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:496:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:500:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:502:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:503:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:507:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:510:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:511:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:513:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:516:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:518:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:520:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:524:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:526:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:528:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:531:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:533:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:538:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:540:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:543:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:552:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar.py:553:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:556:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar.py:562:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar.py:563:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar.py:564:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:567:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:573:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:586:0: C0305: Trailing newlines (trailing-newlines)
# caesar.py:391:14: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar.py:48:0: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:62:8: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar.py:60:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:88:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:92:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:100:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:120:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:123:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:127:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:139:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:161:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:168:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:198:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:202:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:210:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:216:16: W0101: Unreachable code (unreachable)
# caesar.py:224:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:227:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:231:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:244:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:262:61: W0613: Unused argument 'charenc' (unused-argument)
# caesar.py:269:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:275:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:339:4: W0621: Redefining name 'args' from outer scope (line 566) (redefined-outer-name)
# caesar.py:343:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:347:7: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:347:25: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:348:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:348:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:351:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:357:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:357:25: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:358:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:358:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:361:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:367:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:367:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:370:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:370:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:401:13: W0621: Redefining name 'args' from outer scope (line 566) (redefined-outer-name)
# caesar.py:420:12: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar.py:409:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:411:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:414:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:427:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:430:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:443:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:445:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:447:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:450:21: E1120: No value for argument 'charenc' in staticmethod call (no-value-for-parameter)
# caesar.py:458:11: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:460:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar.py:497:12: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar.py:485:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:521:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:527:21: E1120: No value for argument 'charenc' in staticmethod call (no-value-for-parameter)
# caesar.py:554:7: W0703: Catching too general exception Exception (broad-except)
# caesar.py:553:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:553:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:557:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:558:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:559:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:560:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:561:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:566:8: C0103: Constant name "args" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:34:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
#
# -------------------------------------------------------------------
#
# Your code has been rated at -0.85/10 (previous run: 6.62/10, -7.47)
# ************* Module caesar
# caesar.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar.py:156:0: C0301: Line too long (109/100) (line-too-long)
# caesar.py:262:0: C0301: Line too long (109/100) (line-too-long)
# caesar.py:417:0: C0301: Line too long (116/100) (line-too-long)
# caesar.py:425:0: C0301: Line too long (129/100) (line-too-long)
# caesar.py:48:0: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:61:8: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar.py:59:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:88:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:97:58: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:114:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:134:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:159:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:168:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:196:20: R1722: Consider using sys.exit() (consider-using-sys-exit)
# caesar.py:205:58: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:211:16: W0101: Unreachable code (unreachable)
# caesar.py:217:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:237:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:257:61: W0613: Unused argument 'charenc' (unused-argument)
# caesar.py:265:4: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar.py:273:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:368:4: W0621: Redefining name 'args' from outer scope (line 611) (redefined-outer-name)
# caesar.py:371:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:377:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:377:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:381:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:387:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:387:25: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:392:11: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar.py:399:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:399:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar.py:432:13: W0621: Redefining name 'args' from outer scope (line 611) (redefined-outer-name)
# caesar.py:450:12: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar.py:439:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:478:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:485:21: E1120: No value for argument 'charenc' in staticmethod call (no-value-for-parameter)
# caesar.py:533:12: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar.py:521:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:562:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:568:21: E1120: No value for argument 'charenc' in staticmethod call (no-value-for-parameter)
# caesar.py:599:7: W0703: Catching too general exception Exception (broad-except)
# caesar.py:598:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:598:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:602:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:603:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:604:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:605:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:606:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:611:8: C0103: Constant name "args" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:34:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
#
# -------------------------------------------------------------------
#
# Your code has been rated at 7.05/10 (previous run: -0.85/10, +7.90)
# usage: ipykernel_launcher.py [-h] [-i] [-t T | -f F] [-e | -d] [-k [K]]
# ipykernel_launcher.py: error: usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
