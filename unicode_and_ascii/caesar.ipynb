# %%
''' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '''
# Out:
# ' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '

# %% [markdown]
# 1. option to choose file or enter text - done
# 2. if key is 0 or equivalent take a random key - not required
# 3. select random key for encryption itself - done
# 4. file not found break - done
# 5. Issue with \n\r etc - done
# 6. positional parameters
# 7. brute force
# 8. auto convert to py - done
# 9. if letter not found return same letter - done
# 10. Unicode support - done
# 11. command line arguments
# 12. better file memory management
# 13. Improved questions
# 14. improved file names saved
# 15. save key in a file
# 16. make a exe

# %%
import chardet
import argparse
import sys
from os import path
from random import randint

# %%
DICT = [chr(letter) for letter in range(sys.maxunicode)]
DICT = DICT[::3] + DICT[1::3] + DICT[2::3] 
DICT_LEN = sys.maxunicode

# %%
def detect_encoding(file):
    
    with open(file, "rb") as f:
        rawdata = f.read()
        result = chardet.detect(rawdata)
        charenc = result['encoding']
    return charenc

# %%
class Encrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be encrypted. '''
        text = str(input('Enter the text to be encrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be encrypted. '''  
        while True:
            file = str(input('''Enter the file with path to be encrypted :  '''))
            file = path.abspath(file)          # Get absolute path 
            charenc = detect_encoding(file)    # Detect encoding
            
            try:
                with open(file,'r', encoding=charenc) as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            #except UnicodeDecodeError:
            #    with open(file,'r') as f:
            #        f_contents = f.read()
            #        break
            else:
                break
        
        return f_contents, file
    
                
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Key needs to be a positive or negative number! : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN   #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            for index,letter in enumerate(DICT):

                new_index = (en_key  + index) % DICT_LEN   # since new_index will go over dict_len , cycle  
                DICT_KEYS[letter] = DICT[new_index]        # Creates dictionary map

        return DICT_KEYS, original_key, en_key                   
    
    
    @staticmethod
    def encrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns encrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key

    
    @staticmethod
    def encrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes encrypted text to file. '''
        new_file = path.splitext(file)[0] +  '.cen'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file,'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
class Decrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be decrypted. '''
        text = str(input('Enter the text to be Decrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be decrypted. ''' 
        while True:
            file = str(input('''Enter the file with path to be decrypted :  '''))
            file = path.abspath(file)
            try:
                with open(file,'r', encoding="utf-8") as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:   
                return f_contents, file 
                break
    
    
    @staticmethod
    def get_key():
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        while True:
            try:
                en_key = int(input('Enter the key. Normal or shortened. : '))
                if type(en_key) == type(float()):
                    raise ValueError
            except ValueError:
                print(f'Key can only be a positive or negative integer number!')
            else:
                break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN      #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            en_key = -(en_key)      #Decrypt means , negative key 
            for index, letter in enumerate(DICT):

                #new_index = abs( index - en_key ) % DICT_LEN   # since new_index will go over dict_len , cycle  
                new_index = (en_key  + index) % DICT_LEN
                DICT_KEYS[letter] = DICT[new_index]            # Creates dictionary map

        
        #print(DICT_KEYS)
        return DICT_KEYS, original_key, abs(en_key)                   
    
    
    @staticmethod
    def decrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns decrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
   
    @staticmethod
    def decrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes decrypted text to file. '''
        new_file = path.splitext(file)[0] + '.cde'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file, 'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
def choices():
    
    ''' This function takes in initial user choices. '''
    while True:
        ced = str(input('Encryption or Decryption [E/D] ? : ')).lower() 
        if ced not in {'e','d'}:
            continue
        while True:
            ctf = str(input('Text or File [T/F] ? : ')).lower() 
            if ctf not in {'t','f'}:
                continue
            break
        break
    return ced, ctf

# %%
def key_choice():
    
    ''' This function decides whether user wants to enter a key or not. '''
    while True:
        cyn = str(input('Want to enter a key or select a random key [Y/N] ? :')).lower()
        if cyn not in {'y','n'}:
            continue
        break
    return cyn

# %%
def cmdline():

    text=str()
    file=str()
    key=int()
    
    parser = argparse.ArgumentParser()
    
    ### Interactive mode ###
    parser.add_argument("-i", "--interactive", action="store_true", help="Interactive mode")
    
    ### Mutually exclusive group of text and file, since both cannot be together ###
    group_tf = parser.add_mutually_exclusive_group()
    group_tf.add_argument("-t", "--text", type=str, help="Text input")
    group_tf.add_argument("-f", "--file-path", type=str, help="File input")
    
    ### Mutually exclusive group of encrypt and decrypt, since both cannot be together ###
    group_ed = parser.add_mutually_exclusive_group()
    group_ed.add_argument("-e", "--encypt", action="store_true", help="Encrypt")
    group_ed.add_argument("-d", "--decrypt", action="store_true", help="Decrypt")
    
    
    parser.add_argument("-k", type=int,  help="Key")
    
    args = parser.parse_args()
    
    
    if args.i == True:
        print
        
    
    ### If interactive only return interactive ###
    #if args.i:
    #    return args.i
    # 
    #else:
    
    #if args.k == None:
    #print('Random key will be taken')
    
    #print('XYZ')
    
    
    #return args.i,args.k

# %%
def main():
    
    ''' This is the main function. This controls enverything. '''
    
 
    i = cmdline()
    if i == True:
        print('YYYYYYYYYYYYYYYYYY')
    elif i == 1:

        ### Welcome ###
        print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
        print('Encryption will take place for ascii characters only.')
        print('Enter either text or file you want to encrypt and a key.')
        print('For multiline input, use the file option.')
        print('Key can be a positive or negative number.')
        print('\n')
        print('Have fun!!!  ¯\_(^^)_/¯ ')
        print('\n\n')
        
        ### Choices ###
        ced, ctf = choices()
        if ced == 'e':      ### Encrypt ###
            
            e = Encrypt()
            
            if ctf == 't':      ### Text input ###
                text = e.get_text()
                cyn = key_choice()
                
                if cyn == 'y':      ### Key input ###
                    dict_keys, original_key, new_key = e.get_key()
                else:
                    dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
                
                
                result = e.encrypt_text(text, dict_keys, original_key, new_key)      ### Encryption ###
                print('\n\n')
                print(f'''Encrypted text : '{result[0]}' ''')
                print(f'''Key            : '{result[1]}' ''')  
                print(f'''Shortened key  : '{result[2]}' ''')
            
            
            if ctf == 'f':      ### File input ###
                text, file = e.get_text_from_file()
                cyn = key_choice()
                if cyn == 'y':      ### Key input ### 
                    dict_keys, original_key, new_key = e.get_key()
                else:
                    dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                    
                result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key)
                
                print('\n\n')
                print(f'''Encrypted file : '{result[0]}' ''')
                print(f'''Key            : '{result[1]}' ''')  
                print(f'''Shortened key  : '{result[2]}' ''')
                               
        else:
            
            d = Decrypt()
    
            if ctf == 't':      ### Text input ###
                text = d.get_text()            
                dict_keys, original_key, new_key = d.get_key()
                
                result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
                
                print('\n\n')
                print(f'''Decrypted text : '{result[0]}' ''')
                print(f'''Key            : '{result[1]}' ''')  
                print(f'''Shortened key  : '{result[2]}' ''')
                
    
            if ctf == 'f':      ### File input ###
                text, file = d.get_text_from_file()
                dict_keys, original_key, new_key = d.get_key()
                    
                result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key)
                
                print('\n\n')
                print(f'''Decrypted file : '{result[0]}' ''')
                print(f'''Key            : '{result[1]}' ''')  
                print(f'''Shortened key  : '{result[2]}' ''')
    else:
        print('NOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO!!!')

# %%
### This is to convert ipynb files to py if run in Jupyter notebook ###
### Also this will cause no problem even if .py file is directly run ###
try :
    terminal = get_ipython().__class__.__name__ 
except Exception:
    pass
else :
    if get_ipython().__class__.__name__ == 'ZMQInteractiveShell':
        # !jupyter nbconvert --to script caesar.ipynb
        # !pylint caesar.py
        # !autopep8 --in-place --aggressive caesar.py
        # !pylint caesar.py  
finally :
    if __name__ == "__main__" :
        main()
# Out:
# [NbConvertApp] Converting notebook caesar.ipynb to script
# [NbConvertApp] Writing 14237 bytes to caesar.py
# ************* Module caesar
# caesar.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:18:50: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:19:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:20:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:24:24: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:41:42: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:49:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:61:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:62:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:63:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:66:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:70:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:71:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:72:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:74:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:75:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:78:66: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:80:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:82:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar.py:92:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:94:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:95:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:96:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:99:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:103:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:108:0: C0301: Line too long (107/100) (line-too-long)
# caesar.py:115:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:117:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:119:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:120:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:121:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:121:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:122:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:124:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:125:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:125:0: C0301: Line too long (120/100) (line-too-long)
# caesar.py:126:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar.py:128:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:128:0: C0301: Line too long (106/100) (line-too-long)
# caesar.py:131:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:132:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:133:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:136:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:139:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:139:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:139:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:141:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:144:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:148:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:148:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:149:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding="utf-8") as f:
#
#                           ^ (bad-whitespace)
# caesar.py:151:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:153:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:155:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:162:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:163:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:164:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:167:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:171:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:172:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:173:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:175:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:176:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:181:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar.py:185:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:186:39: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:188:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:189:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:192:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:196:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:207:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:209:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:211:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:212:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:213:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:213:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:214:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:216:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:217:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:217:0: C0301: Line too long (123/100) (line-too-long)
# caesar.py:218:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:221:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:221:0: C0301: Line too long (111/100) (line-too-long)
# caesar.py:225:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:227:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:228:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:229:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:232:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:235:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:235:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:235:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:236:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:239:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:243:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:243:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:246:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:254:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:257:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:258:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar.py:261:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:262:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar.py:273:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:277:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar.py:288:8: C0326: Exactly one space required around assignment
#     text=str()
#
#         ^ (bad-whitespace)
# caesar.py:289:8: C0326: Exactly one space required around assignment
#     file=str()
#
#         ^ (bad-whitespace)
# caesar.py:290:7: C0326: Exactly one space required around assignment
#     key=int()
#
#        ^ (bad-whitespace)
# caesar.py:291:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:293:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:296:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:301:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:306:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:307:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:308:38: C0326: Exactly one space required after comma
#     parser.add_argument("-k", type=int,  help="Key")
#
#                                       ^ (bad-whitespace)
# caesar.py:309:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:311:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:312:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:315:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:316:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:320:5: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:322:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:325:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:327:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:328:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:330:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:337:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:339:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:340:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:347:0: C0301: Line too long (121/100) (line-too-long)
# caesar.py:347:120: C0326: No space allowed before bracket
#         print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                         ^ (bad-whitespace)
# caesar.py:355:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:359:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:361:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:365:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:369:81: C0326: Exactly one space required after comma
#                     dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                                  ^ (bad-whitespace)
# caesar.py:370:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:371:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:372:0: C0301: Line too long (103/100) (line-too-long)
# caesar.py:375:61: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:377:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:378:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:382:53: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:385:81: C0326: Exactly one space required after comma
#                     dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                                  ^ (bad-whitespace)
# caesar.py:386:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:388:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:391:61: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:393:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:395:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:397:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:399:35: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:401:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:402:0: C0301: Line too long (103/100) (line-too-long)
# caesar.py:403:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:406:61: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:408:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:409:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:413:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:415:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:418:61: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:422:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:430:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar.py:431:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:434:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar.py:440:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar.py:441:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar.py:443:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:456:0: C0305: Trailing newlines (trailing-newlines)
# caesar.py:353:14: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar.py:48:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar.py:50:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:82:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:102:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:105:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:109:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:121:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:149:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:181:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:187:16: W0101: Unreachable code (unreachable)
# caesar.py:195:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:201:19: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:213:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:244:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:286:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar.py:313:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:314:8: W0104: Statement seems to have no effect (pointless-statement)
# caesar.py:288:4: W0612: Unused variable 'text' (unused-variable)
# caesar.py:289:4: W0612: Unused variable 'file' (unused-variable)
# caesar.py:290:4: W0612: Unused variable 'key' (unused-variable)
# caesar.py:341:4: E1111: Assigning result of a function call, where the function has no return (assignment-from-no-return)
# caesar.py:342:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:360:12: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:396:12: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:336:0: R0912: Too many branches (13/12) (too-many-branches)
# caesar.py:336:0: R0915: Too many statements (60/50) (too-many-statements)
# caesar.py:432:7: W0703: Catching too general exception Exception (broad-except)
# caesar.py:431:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:431:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:435:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:436:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:437:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:438:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:439:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:31:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
# caesar.py:32:0: C0411: standard import "import sys" should be placed before "import chardet" (wrong-import-order)
# caesar.py:33:0: C0411: standard import "from os import path" should be placed before "import chardet" (wrong-import-order)
# caesar.py:34:0: C0411: standard import "from random import randint" should be placed before "import chardet" (wrong-import-order)
#
# -------------------------------------------------------------------
#
# Your code has been rated at -1.73/10 (previous run: 7.01/10, -8.75)
# ************* Module caesar
# caesar.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar.py:139:0: C0301: Line too long (109/100) (line-too-long)
# caesar.py:231:0: C0301: Line too long (109/100) (line-too-long)
# caesar.py:350:0: C0301: Line too long (120/100) (line-too-long)
# caesar.py:48:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar.py:50:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:80:58: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:97:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:117:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:149:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:176:58: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:182:16: W0101: Unreachable code (unreachable)
# caesar.py:188:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:206:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:241:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:282:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar.py:321:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:322:8: W0104: Statement seems to have no effect (pointless-statement)
# caesar.py:284:4: W0612: Unused variable 'text' (unused-variable)
# caesar.py:285:4: W0612: Unused variable 'file' (unused-variable)
# caesar.py:286:4: W0612: Unused variable 'key' (unused-variable)
# caesar.py:344:4: E1111: Assigning result of a function call, where the function has no return (assignment-from-no-return)
# caesar.py:345:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar.py:363:12: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:401:12: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:341:0: R0912: Too many branches (13/12) (too-many-branches)
# caesar.py:341:0: R0915: Too many statements (60/50) (too-many-statements)
# caesar.py:436:7: W0703: Catching too general exception Exception (broad-except)
# caesar.py:435:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:435:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:439:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:440:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:441:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:442:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:443:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:31:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
# caesar.py:32:0: C0411: standard import "import sys" should be placed before "import chardet" (wrong-import-order)
# caesar.py:33:0: C0411: standard import "from os import path" should be placed before "import chardet" (wrong-import-order)
# caesar.py:34:0: C0411: standard import "from random import randint" should be placed before "import chardet" (wrong-import-order)
#
# -------------------------------------------------------------------
#
# Your code has been rated at 6.68/10 (previous run: -1.73/10, +8.42)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0eeb7d3f33cb> in <module>
#      13 finally :
#      14     if __name__ == "__main__" :
# ---> 15         main()
#      16
#
# <ipython-input-10-296148ac945d> in main()
#       4
#       5
# ----> 6     i = cmdline()
#       7     if i == True:
#       8         print('YYYYYYYYYYYYYYYYYY')
#
# <ipython-input-9-ba28229f6ed2> in cmdline()
#      26
#      27
# ---> 28     if args.i == True:
#      29         print
#      30
#
# AttributeError: 'Namespace' object has no attribute 'i'
