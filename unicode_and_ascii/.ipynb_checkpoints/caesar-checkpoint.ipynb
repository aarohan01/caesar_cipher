# %%
''' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '''
# Out:
# ' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '

# %% [markdown]
# 1. option to choose file or enter text - done
# 2. if key is 0 or equivalent take a random key - not required
# 3. select random key for encryption itself - done
# 4. file not found break - done
# 5. Issue with \n\r etc - done
# 6. positional parameters
# 7. brute force
# 8. auto convert to py - done
# 9. if letter not found return same letter - done
# 10. Unicode support - done
# 11. command line arguments
# 12. better file memory management

# %%
import chardet
import sys
from os import path
from random import randint

# %%
DICT = [chr(letter) for letter in range(sys.maxunicode)]
DICT = DICT[::3] + DICT[1::3] + DICT[2::3] 
DICT_LEN = sys.maxunicode

# %%
def detect_encoding(file):
    
    with open(file, "rb") as f:
        rawdata = f.read()
        result = chardet.detect(rawdata)
        charenc = result['encoding']
    return charenc

# %%
class Encrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be encrypted. '''
        text = str(input('Enter the text to be encrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be encrypted. '''  
        while True:
            file = str(input('''Enter the file with path to be encrypted :  '''))
            file = path.abspath(file)          # Get absolute path 
            charenc = detect_encoding(file)    # Detect encoding
            
            try:
                with open(file,'r', encoding=charenc) as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            #except UnicodeDecodeError:
            #    with open(file,'r') as f:
            #        f_contents = f.read()
            #        break
            else:
                break
        
        return f_contents, file
    
                
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Key needs to be a positive or negative number! : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN   #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            for index,letter in enumerate(DICT):

                new_index = (en_key  + index) % DICT_LEN   # since new_index will go over dict_len , cycle  
                DICT_KEYS[letter] = DICT[new_index]        # Creates dictionary map

        return DICT_KEYS, original_key, en_key                   
    
    
    @staticmethod
    def encrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns encrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key

    
    @staticmethod
    def encrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes encrypted text to file. '''
        new_file = path.splitext(file)[0] +  '.cen'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file,'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
class Decrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be decrypted. '''
        text = str(input('Enter the text to be Decrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be decrypted. ''' 
        while True:
            file = str(input('''Enter the file with path to be decrypted :  '''))
            file = path.abspath(file)
            try:
                with open(file,'r', encoding="utf-8") as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:   
                return f_contents, file 
                break
    
    
    @staticmethod
    def get_key():
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        while True:
            try:
                en_key = int(input('Enter the key. Normal or shortened. : '))
                if type(en_key) == type(float()):
                    raise ValueError
            except ValueError:
                print(f'Key can only be a positive or negative integer number!')
            else:
                break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN      #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            en_key = -(en_key)      #Decrypt means , negative key 
            for index, letter in enumerate(DICT):

                #new_index = abs( index - en_key ) % DICT_LEN   # since new_index will go over dict_len , cycle  
                new_index = (en_key  + index) % DICT_LEN
                DICT_KEYS[letter] = DICT[new_index]            # Creates dictionary map

        
        #print(DICT_KEYS)
        return DICT_KEYS, original_key, abs(en_key)                   
    
    
    @staticmethod
    def decrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns decrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
   
    @staticmethod
    def decrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes decrypted text to file. '''
        new_file = path.splitext(file)[0] + '.cde'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file, 'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
def choices():
    
    ''' This function takes in initial user choices. '''
    while True:
        ced = str(input('Encryption or Decryption [E/D] ? : ')).lower() 
        if ced not in {'e','d'}:
            continue
        while True:
            ctf = str(input('Text or File [T/F] ? : ')).lower() 
            if ctf not in {'t','f'}:
                continue
            break
        break
    return ced, ctf

# %%
def key_choice():
    
    ''' This function decides whether user wants to enter a key or not. '''
    while True:
        cyn = str(input('Want to enter a key or select a random key [Y/N] ? :')).lower()
        if cyn not in {'y','n'}:
            continue
        break
    return cyn

# %%
def cmdline():
    pass

# %%
def main():
    
    ''' This is the main function. This controls enverything. '''
    ### Welcome ###
    print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
    print('Encryption will take place for ascii characters only.')
    print('Enter either text or file you want to encrypt and a key.')
    print('For multiline input, use the file option.')
    print('Key can be a positive or negative number.')
    print('\n')
    print('Have fun!!!  ¯\_(^^)_/¯ ')
    print('\n\n')
    
    ### Choices ###
    ced, ctf = choices()
    if ced == 'e':      ### Encrypt ###
        
        e = Encrypt()
        
        if ctf == 't':      ### Text input ###
            text = e.get_text()
            cyn = key_choice()
            
            if cyn == 'y':      ### Key input ###
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
            
            
            result = e.encrypt_text(text, dict_keys, original_key, new_key)      ### Encryption ###
            print('\n\n')
            print(f'''Encrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
        
        
        if ctf == 'f':      ### File input ###
            text, file = e.get_text_from_file()
            cyn = key_choice()
            if cyn == 'y':      ### Key input ### 
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key)
            
            print('\n\n')
            print(f'''Encrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
                           
    else:
        
        d = Decrypt()

        if ctf == 't':      ### Text input ###
            text = d.get_text()            
            dict_keys, original_key, new_key = d.get_key()
            
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
            
            print('\n\n')
            print(f'''Decrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
            

        if ctf == 'f':      ### File input ###
            text, file = d.get_text_from_file()
            dict_keys, original_key, new_key = d.get_key()
                
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key)
            
            print('\n\n')
            print(f'''Decrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')

# %%
### This is to convert ipynb files to py if run in Jupyter notebook ###
### Also this will cause no problem even if .py file is directly run ###
try :
    terminal = get_ipython().__class__.__name__ 
except Exception:
    pass
else :
    if get_ipython().__class__.__name__ == 'ZMQInteractiveShell':
        # !jupyter nbconvert --to script caesar.ipynb
        # !pylint caesar.py
        # !autopep8 --in-place --aggressive caesar.py
        # !pylint cipher.py  
finally :
    if __name__ == "__main__" :
        main()
# Out:
# [NbConvertApp] Converting notebook caesar.ipynb to script
# [NbConvertApp] Writing 12385 bytes to caesar.py
# ************* Module caesar
# caesar.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:18:50: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:19:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:20:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:36:42: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:44:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:55:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:56:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:57:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:60:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:64:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:65:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:66:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:68:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:69:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:72:66: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:74:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:76:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar.py:86:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:88:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:89:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:90:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:93:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:97:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:102:0: C0301: Line too long (107/100) (line-too-long)
# caesar.py:109:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:111:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:113:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:114:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:115:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:115:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:116:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:118:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:119:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:119:0: C0301: Line too long (120/100) (line-too-long)
# caesar.py:120:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar.py:122:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:122:0: C0301: Line too long (106/100) (line-too-long)
# caesar.py:125:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:126:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:127:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:130:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:133:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:133:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:133:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:135:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:138:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:142:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:142:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:143:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding="utf-8") as f:
#
#                           ^ (bad-whitespace)
# caesar.py:145:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:147:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:149:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:156:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:157:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:158:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:161:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:165:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:166:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:167:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:169:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:170:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:175:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar.py:179:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:180:39: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:182:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:183:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:186:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:190:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:201:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:203:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:205:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:206:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:207:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar.py:207:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar.py:208:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:210:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:211:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:211:0: C0301: Line too long (123/100) (line-too-long)
# caesar.py:212:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:215:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:215:0: C0301: Line too long (111/100) (line-too-long)
# caesar.py:219:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:221:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:222:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:223:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:226:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:229:0: C0301: Line too long (122/100) (line-too-long)
# caesar.py:229:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar.py:229:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:230:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:233:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:237:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar.py:237:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar.py:240:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:248:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:251:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:252:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar.py:255:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:256:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar.py:267:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:271:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar.py:281:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:284:0: C0301: Line too long (117/100) (line-too-long)
# caesar.py:284:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar.py:292:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:296:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:298:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:302:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:306:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:307:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:308:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:312:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:314:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:315:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:319:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:322:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar.py:323:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:325:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:328:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:330:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:332:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:336:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:338:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:340:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:343:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:345:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:350:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:352:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:355:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:357:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:365:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar.py:366:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:369:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar.py:375:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar.py:376:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar.py:378:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar.py:391:0: C0305: Trailing newlines (trailing-newlines)
# caesar.py:290:14: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar.py:43:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar.py:76:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:96:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:99:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar.py:103:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:115:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:143:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:175:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:181:16: W0101: Unreachable code (unreachable)
# caesar.py:189:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:195:19: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar.py:207:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:238:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:297:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:333:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar.py:280:0: R0915: Too many statements (54/50) (too-many-statements)
# caesar.py:367:7: W0703: Catching too general exception Exception (broad-except)
# caesar.py:366:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar.py:366:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:370:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:371:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:372:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:373:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:374:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar.py:27:0: C0411: standard import "import sys" should be placed before "import chardet" (wrong-import-order)
# caesar.py:28:0: C0411: standard import "from os import path" should be placed before "import chardet" (wrong-import-order)
# caesar.py:29:0: C0411: standard import "from random import randint" should be placed before "import chardet" (wrong-import-order)
#
# --------------------------------------------------------------------
#
# Your code has been rated at -0.84/10 (previous run: -0.54/10, -0.29)
# ************* Module cipher.py
# cipher.py:1:0: F0001: No module named cipher.py (fatal)
# Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher's principle.
# Encryption will take place for ascii characters only.
# Enter either text or file you want to encrypt and a key.
# For multiline input, use the file option.
# Key can be a positive or negative number.
#
#
# Have fun!!!  ¯\_(^^)_/¯
#
#
#
# Encryption or Decryption [E/D] ? : e
# Text or File [T/F] ? : t
# Enter the text to be encrypted : Hello
# Want to enter a key or select a random key [Y/N] ? :y
# Enter the key. Key needs to be a positive or negative number! : 4000
#
#
#
# Encrypted text : '⼨⽅⽌⽌⽏'
# Key            : '4000'
# Shortened key  : '4000'
