# %%
''' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '''
# Out:
# ' This module is to encrypt text by using "Caesar cipher". This module uses extended ascii letters from string modules. '

# %% [markdown]
# 1. option to choose file or enter text - done
# 2. if key is 0 or equivalent take a random key - not required
# 3. select random key for encryption itself - done
# 4. file not found break - done
# 5. Issue with \n\r etc - done
# 6. positional parameters
# 7. brute force
# 8. auto convert to py - done
# 9. if letter not found return same letter - done
# 10. Unicode support - done
# 11. command line arguments
# 12. better file memory management
# 13. Improved questions
# 14. improved file names saved
# 15. save key in a file
# 16. make a exe

# %%
import chardet
import argparse
import sys
from os import path
from random import randint

# %%
DICT = [chr(letter) for letter in range(sys.maxunicode)]
DICT_LEN = sys.maxunicode

# %%
### Mashup ###
result = list()
for num in range(0,DICT_LEN,25) :
    result += DICT[num:num+25]
DICT = result

# %%
def detect_encoding(file):
    
    with open(file, "rb") as f:
        rawdata = f.read()
        result = chardet.detect(rawdata)
        charenc = result['encoding']
    return charenc

# %%
class Encrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be encrypted. '''
        text = str(input('Enter the text to be encrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be encrypted. '''  
        while True:
            file = str(input('''Enter the file with path to be encrypted :  '''))
            file = path.abspath(file)          # Get absolute path 
            charenc = detect_encoding(file)    # Detect encoding
            
            try:
                with open(file,'r', encoding=charenc) as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            #except UnicodeDecodeError:
            #    with open(file,'r') as f:
            #        f_contents = f.read()
            #        break
            else:
                break
        
        return f_contents, file
    
                
    
    @staticmethod
    def get_key(en_key=None):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        if en_key == None:
            while True:
                try:
                    en_key = int(input('Enter the key. Key needs to be a positive or negative number! : '))
                    if type(en_key) == type(float()):
                        raise ValueError
                except ValueError:
                    print(f'Key can only be a positive or negative integer number!')
                else:
                    break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN   #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            for index,letter in enumerate(DICT):

                new_index = (en_key  + index) % DICT_LEN   # since new_index will go over dict_len , cycle  
                DICT_KEYS[letter] = DICT[new_index]        # Creates dictionary map

        return DICT_KEYS, original_key, en_key                   
    
    
    @staticmethod
    def encrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns encrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key

    
    @staticmethod
    def encrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes encrypted text to file. '''
        new_file = path.splitext(file)[0] +  '.cen'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file,'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
class Decrypt():
    
    ''' This class is a collection of all methods used to encrypt text. ''' 
        
    @staticmethod
    def get_text():
        
        ''' This function is to get the text that is to be decrypted. '''
        text = str(input('Enter the text to be Decrypted : '))
        return text
    
    
    @staticmethod    
    def get_text_from_file():
        
        ''' This function is to get the text from a file that is to be decrypted. ''' 
        while True:
            file = str(input('''Enter the file with path to be decrypted :  '''))
            file = path.abspath(file)
            try:
                with open(file,'r', encoding="utf-8") as f:
                    f_contents = f.read()
            except FileNotFoundError:
                print('File not found !!! Try again.')
            else:   
                return f_contents, file 
                break
    
    
    @staticmethod
    def get_key(key=False):
        
        ''' This function is to get key value from user. '''
        ### DICT_KEYS are the map of original letters ###
        DICT_KEYS = dict()
        
        ### Input ###
        while True:
            try:
                
                if key == False:                     # no cmdline 
                    en_key = int(input('Enter the key. Normal or shortened. : '))
                else:
                    en_key = key 
                if type(en_key) == type(float()):
                    raise ValueError
            except ValueError:
                print(f'Key can only be a positive or negative integer number!')
            else:
                break
        
        original_key = en_key
        
        ### TURN THE LETTERS ###
        if en_key == 0:       # Key is 0   
           
            DICT_KEYS = { letter:letter for letter in DICT }
        
        else:                      # Key is positive or negative
            
            en_key %= DICT_LEN      #If absolute value of key greater DICT_LEN it will reduce the key else will remain same 
            en_key = -(en_key)      #Decrypt means , negative key 
            for index, letter in enumerate(DICT):

                #new_index = abs( index - en_key ) % DICT_LEN   # since new_index will go over dict_len , cycle  
                new_index = (en_key  + index) % DICT_LEN
                DICT_KEYS[letter] = DICT[new_index]            # Creates dictionary map

        
        #print(DICT_KEYS)
        return DICT_KEYS, original_key, abs(en_key)                   
    
    
    @staticmethod
    def decrypt_text(text, dict_keys, original_key, new_key):
        
        ''' This function returns decrypted text. '''
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
   
    @staticmethod
    def decrypt_text_to_file(text, file, dict_keys, original_key, new_key):
        
        ''' This function writes decrypted text to file. '''
        new_file = path.splitext(file)[0] + '.cde'
        ### Return mapped letter if present or return letter [ Other than ascii characters ] ###
        text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
        with open(new_file, 'w', encoding="utf-8") as f:
            f.write(text)
        
        return new_file, original_key, new_key

# %%
def choices():
    
    ''' This function takes in initial user choices. '''
    while True:
        ced = str(input('Encryption or Decryption [E/D] ? : ')).lower() 
        if ced not in {'e','d'}:
            continue
        while True:
            ctf = str(input('Text or File [T/F] ? : ')).lower() 
            if ctf not in {'t','f'}:
                continue
            break
        break
    return ced, ctf

# %%
def key_choice():
    
    ''' This function decides whether user wants to enter a key or not. '''
    while True:
        cyn = str(input('Want to enter a key or select a random key [Y/N] ? :')).lower()
        if cyn not in {'y','n'}:
            continue
        break
    return cyn

# %%
def cmdline():

    
    parser = argparse.ArgumentParser()
    
    ### Interactive mode ###
    parser.add_argument("-i", "--interactive", dest="i", action="store_true", help="Interactive mode") 

    ### Mutually exclusive group of text and file, since both cannot be together ###
    group_tf = parser.add_mutually_exclusive_group()
    group_tf.add_argument("-t", "--text", dest="t", type=str, help="Text input")
    group_tf.add_argument("-f", "--file-path", dest="f", type=str, help="File input")
    
    ### Mutually exclusive group of encrypt and decrypt, since both cannot be together ###
    group_ed = parser.add_mutually_exclusive_group()
    group_ed.add_argument("-e", "--encypt", dest="e", action="store_true", help="Encrypt") 
    group_ed.add_argument("-d", "--decrypt", dest="d", action="store_true", help="Decrypt") 
    
    ### key parameter ###
    parser.add_argument("-k", "--key", dest="k", type=str, default='x', nargs='?', help="Key") #remember to convert key to int 
    
 
    args = parser.parse_args()
    
    

    print(args)
    ### Interactive mode ###
    #if args.i == True:
    #    return 0
    
    ### T or F condition only ###
    if args.t != None or args.f != None:
        if args.e != True and args.d != True:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.k == 'x':
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
            
            
    ### E or F condition only ###
    if args.e == True or args.d == True:
        if args.t == None and args.f == None:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.k == 'x':
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
    
    ### K condition only ###
    if args.k  != 'x':
        if args.e != True and args.d != True:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        if args.t == None and args.f == None:
            print('\n\n')
            parser.error('usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>')
        
    return args

# %%
def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
    
    ''' This is the main function. This controls enverything. '''
    
 
    ### Welcome ###
    print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
    print('Encryption will take place for ascii characters only.')
    print('Enter either text or file you want to encrypt and a key.')
    print('For multiline input, use the file option.')
    print('Key can be a positive or negative number.')
    print('\n')
    print('Have fun!!!  ¯\_(^^)_/¯ ')
    print('\n\n')
        
    ### Choices ###
    if ced == None and cft == None:     # no cmdline 
        ced, ctf = choices()
        
    if ced == 'e':      ### Encrypt ###
            
        e = Encrypt()
            
        if ctf == 't':      ### Text input ###
            if text == None:         # no cmdline
                text = e.get_text()
            if cyn == None:          # no cmdline
                cyn = key_choice()
    
            
            if cyn =='x':      # cmdline 
                dict_keys, original_key, new_key = e.get_key(en_key=key)   
            elif cyn == 'y':      ### Key input ###
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
                
                
            result = e.encrypt_text(text, dict_keys, original_key, new_key)      ### Encryption ###
            print('\n\n')
            print(f'''Encrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
            
            
        if ctf == 'f':      ### File input ###
            text, file = e.get_text_from_file()
            cyn = key_choice()
            if cyn == 'y':      ### Key input ### 
                dict_keys, original_key, new_key = e.get_key()
            else:
                dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
                    
            result = e.encrypt_text_to_file(text, file, dict_keys, original_key, new_key)
                
            print('\n\n')
            print(f'''Encrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
                               
    else:
            
        d = Decrypt()
    
        if ctf == 't':      ### Text input ###
            text = d.get_text()            
            dict_keys, original_key, new_key = d.get_key()
                
            result = d.decrypt_text(text, dict_keys, original_key, new_key)      ### Decryption ###
                
            print('\n\n')
            print(f'''Decrypted text : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')
                
    
        if ctf == 'f':      ### File input ###
            text, file = d.get_text_from_file()
            dict_keys, original_key, new_key = d.get_key()
                    
            result = d.decrypt_text_to_file(text, file, dict_keys, original_key, new_key)
                
            print('\n\n')
            print(f'''Decrypted file : '{result[0]}' ''')
            print(f'''Key            : '{result[1]}' ''')  
            print(f'''Shortened key  : '{result[2]}' ''')

# %%
### This is to convert ipynb files to py if run in Jupyter notebook ###
### Also this will cause no problem even if .py file is directly run ###
try :
    terminal = get_ipython().__class__.__name__ 
except Exception:
    pass
else :
    if get_ipython().__class__.__name__ == 'ZMQInteractiveShell':
        # !jupyter nbconvert --to script caesar_cmd.ipynb
        # !pylint caesar_cmd.py
        # !autopep8 --in-place --aggressive caesar_cmd.py
        # !pylint caesar_cmd.py  
finally :
    if __name__ == "__main__" :
        cmd = cmdline()
        if cmd.i:
            main()
        else:
            
            ### encrypt or decrypt ###
            if cmd.e:
                ced ='e'
            else:
                ced ='d'
            
            ### text or file ###
            if cmd.t != None:
                ctf = 't'
            else:
                ctf = 'f'
            
            ### Key or No key ###
            #if cmd.k == None:
            #    cyn = 'n'
            #else: 
            #    cyn = 'y'
            cyn = 'x'    
                
            
        main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
# Out:
# [NbConvertApp] Converting notebook caesar_cmd.ipynb to script
# [NbConvertApp] Writing 16198 bytes to caesar_cmd.py
# ************* Module caesar_cmd
# caesar_cmd.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar_cmd.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:18:50: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:19:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:20:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:24:24: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:49:18: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,25) :
#
#                   ^ (bad-whitespace)
# caesar_cmd.py:49:27: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,25) :
#
#                            ^ (bad-whitespace)
# caesar_cmd.py:49:32: C0326: No space allowed before :
# for num in range(0,DICT_LEN,25) :
#
#                                 ^ (bad-whitespace)
# caesar_cmd.py:58:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:70:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:71:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:72:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:75:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:79:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:80:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:81:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:83:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:84:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:87:66: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:89:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:91:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:101:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:103:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:104:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:105:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:108:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:112:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:117:0: C0301: Line too long (107/100) (line-too-long)
# caesar_cmd.py:124:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:126:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:128:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:129:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:130:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cmd.py:130:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cmd.py:131:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:133:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:134:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:134:0: C0301: Line too long (120/100) (line-too-long)
# caesar_cmd.py:135:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar_cmd.py:137:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:137:0: C0301: Line too long (106/100) (line-too-long)
# caesar_cmd.py:140:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:141:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:142:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:145:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:148:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cmd.py:148:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:148:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:150:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:153:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:157:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:157:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:158:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding="utf-8") as f:
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:160:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:162:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:164:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:171:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:172:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:173:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:176:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:180:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:181:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:182:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:184:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:185:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:190:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:194:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:195:39: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:197:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:198:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:201:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:205:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:209:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:210:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:213:32: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:220:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:222:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:224:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:225:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:226:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cmd.py:226:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cmd.py:227:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:229:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:230:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:230:0: C0301: Line too long (123/100) (line-too-long)
# caesar_cmd.py:231:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:234:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:234:0: C0301: Line too long (111/100) (line-too-long)
# caesar_cmd.py:238:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:240:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:241:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:242:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:245:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:248:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cmd.py:248:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:248:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:249:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:252:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:256:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:256:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:259:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:267:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:270:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:271:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:274:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:275:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:286:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:290:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:301:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:303:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:305:102: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:305:0: C0301: Line too long (102/100) (line-too-long)
# caesar_cmd.py:311:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:314:90: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:315:91: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:316:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:318:126: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:318:0: C0301: Line too long (126/100) (line-too-long)
# caesar_cmd.py:319:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:320:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:322:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:323:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:329:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:338:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:339:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:348:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:350:15: C0326: Exactly one space required before comparison
#     if args.k  != 'x':
#
#                ^^ (bad-whitespace)
# caesar_cmd.py:357:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:359:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:365:17: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                  ^ (bad-whitespace)
# caesar_cmd.py:365:26: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:365:35: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                                    ^ (bad-whitespace)
# caesar_cmd.py:365:45: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                                              ^ (bad-whitespace)
# caesar_cmd.py:365:55: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                                                        ^ (bad-whitespace)
# caesar_cmd.py:366:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:368:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:369:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:371:0: C0301: Line too long (117/100) (line-too-long)
# caesar_cmd.py:371:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar_cmd.py:379:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:381:52: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:383:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:385:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:387:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:393:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:394:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:395:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:395:19: C0326: Exactly one space required after comparison
#             if cyn =='x':      # cmdline
#
#                    ^^ (bad-whitespace)
# caesar_cmd.py:396:72: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:400:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar_cmd.py:401:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:402:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:406:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:408:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:409:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:413:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:416:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar_cmd.py:417:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:419:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:422:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:424:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:426:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:428:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:430:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:432:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:434:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:437:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:439:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:440:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:444:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:446:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:449:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:452:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:460:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar_cmd.py:461:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:464:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar_cmd.py:470:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar_cmd.py:471:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:476:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:479:20: C0326: Exactly one space required after assignment
#                 ced ='e'
#
#                     ^ (bad-whitespace)
# caesar_cmd.py:481:20: C0326: Exactly one space required after assignment
#                 ced ='d'
#
#                     ^ (bad-whitespace)
# caesar_cmd.py:482:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:488:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:492:18: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:494:21: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:495:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:496:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:497:16: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                 ^ (bad-whitespace)
# caesar_cmd.py:497:20: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                     ^ (bad-whitespace)
# caesar_cmd.py:497:24: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                         ^ (bad-whitespace)
# caesar_cmd.py:497:30: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:497:36: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                                     ^ (bad-whitespace)
# caesar_cmd.py:498:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:511:0: C0305: Trailing newlines (trailing-newlines)
# caesar_cmd.py:377:14: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar_cmd.py:48:0: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:57:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cmd.py:61:8: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar_cmd.py:59:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:91:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:111:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:114:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:118:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cmd.py:130:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:158:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:190:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:196:16: W0101: Unreachable code (unreachable)
# caesar_cmd.py:204:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:210:19: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar_cmd.py:214:19: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cmd.py:226:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:257:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:270:8: W0621: Redefining name 'ced' from outer scope (line 479) (redefined-outer-name)
# caesar_cmd.py:274:12: W0621: Redefining name 'ctf' from outer scope (line 485) (redefined-outer-name)
# caesar_cmd.py:289:8: W0621: Redefining name 'cyn' from outer scope (line 494) (redefined-outer-name)
# caesar_cmd.py:299:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cmd.py:331:7: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar_cmd.py:331:25: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar_cmd.py:332:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:332:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:341:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar_cmd.py:341:25: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar_cmd.py:342:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:342:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:351:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:351:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:354:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:354:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:365:9: W0621: Redefining name 'ced' from outer scope (line 479) (redefined-outer-name)
# caesar_cmd.py:365:18: W0621: Redefining name 'ctf' from outer scope (line 485) (redefined-outer-name)
# caesar_cmd.py:365:27: W0621: Redefining name 'cyn' from outer scope (line 494) (redefined-outer-name)
# caesar_cmd.py:403:12: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar_cmd.py:365:0: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar_cmd.py:381:7: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:381:23: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:381:23: E0602: Undefined variable 'cft' (undefined-variable)
# caesar_cmd.py:386:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:389:15: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:391:15: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:427:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:365:0: R0912: Too many branches (14/12) (too-many-branches)
# caesar_cmd.py:365:0: R0915: Too many statements (59/50) (too-many-statements)
# caesar_cmd.py:462:7: W0703: Catching too general exception Exception (broad-except)
# caesar_cmd.py:461:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:461:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:465:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:466:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:467:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:468:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:469:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:472:8: C0103: Constant name "cmd" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:479:16: C0103: Constant name "ced" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:481:16: C0103: Constant name "ced" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:484:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar_cmd.py:485:16: C0103: Constant name "ctf" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:487:16: C0103: Constant name "ctf" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:494:12: C0103: Constant name "cyn" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:31:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
# caesar_cmd.py:32:0: C0411: standard import "import sys" should be placed before "import chardet" (wrong-import-order)
# caesar_cmd.py:33:0: C0411: standard import "from os import path" should be placed before "import chardet" (wrong-import-order)
# caesar_cmd.py:34:0: C0411: standard import "from random import randint" should be placed before "import chardet" (wrong-import-order)
#
# ------------------------------------
#
# Your code has been rated at -2.47/10
# c:\users\tcs1128747\appdata\local\continuum\anaconda3\lib\site-packages\pep8.py:110: FutureWarning: Possible nested set at position 1
#   EXTRANEOUS_WHITESPACE_REGEX = re.compile(r'[[({] | []}),;:]')
# Usage: autopep8 [options] [filename [filename ...]]
#
# autopep8: error: no such option: --aggressive
# ************* Module caesar_cmd
# caesar_cmd.py:7:0: C0301: Line too long (125/100) (line-too-long)
# caesar_cmd.py:10:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:11:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:12:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:15:26: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:18:50: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:19:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:20:28: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:24:24: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:49:18: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,25) :
#
#                   ^ (bad-whitespace)
# caesar_cmd.py:49:27: C0326: Exactly one space required after comma
# for num in range(0,DICT_LEN,25) :
#
#                            ^ (bad-whitespace)
# caesar_cmd.py:49:32: C0326: No space allowed before :
# for num in range(0,DICT_LEN,25) :
#
#                                 ^ (bad-whitespace)
# caesar_cmd.py:58:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:70:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:71:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:72:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:75:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:79:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:80:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:81:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:83:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:84:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:87:66: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:89:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:91:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding=charenc) as f:
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:101:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:103:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:104:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:105:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:108:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:112:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:117:0: C0301: Line too long (107/100) (line-too-long)
# caesar_cmd.py:124:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:126:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:128:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:129:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:130:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cmd.py:130:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cmd.py:131:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:133:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:134:120: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:134:0: C0301: Line too long (120/100) (line-too-long)
# caesar_cmd.py:135:21: C0326: Exactly one space required after comma
#             for index,letter in enumerate(DICT):
#
#                      ^ (bad-whitespace)
# caesar_cmd.py:137:106: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:137:0: C0301: Line too long (106/100) (line-too-long)
# caesar_cmd.py:140:46: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:141:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:142:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:145:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:148:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cmd.py:148:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:148:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:150:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:153:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:157:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:157:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:158:26: C0326: Exactly one space required after comma
#         with open(new_file,'w', encoding="utf-8") as f:
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:160:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:162:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:164:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:171:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:172:75: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:173:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:176:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:180:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:181:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:182:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:184:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:185:85: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:190:30: C0326: Exactly one space required after comma
#                 with open(file,'r', encoding="utf-8") as f:
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:194:17: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:195:39: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:197:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:198:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:201:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:205:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:209:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:210:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:213:32: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:220:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:222:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:224:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:225:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:226:24: C0326: No space allowed after bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                         ^ (bad-whitespace)
# caesar_cmd.py:226:59: C0326: No space allowed before bracket
#             DICT_KEYS = { letter:letter for letter in DICT }
#
#                                                            ^ (bad-whitespace)
# caesar_cmd.py:227:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:229:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:230:123: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:230:0: C0301: Line too long (123/100) (line-too-long)
# caesar_cmd.py:231:65: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:234:111: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:234:0: C0301: Line too long (111/100) (line-too-long)
# caesar_cmd.py:238:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:240:51: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:241:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:242:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:245:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:248:0: C0301: Line too long (122/100) (line-too-long)
# caesar_cmd.py:248:23: C0326: No space allowed after bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:248:97: C0326: No space allowed before bracket
#         return ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ]), original_key, new_key
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:249:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:252:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:256:23: C0326: No space allowed after bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                        ^ (bad-whitespace)
# caesar_cmd.py:256:97: C0326: No space allowed before bracket
#         text = ''.join([ dict_keys[letter] if letter in dict_keys else letter for letter in text ])
#
#                                                                                                  ^ (bad-whitespace)
# caesar_cmd.py:259:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:267:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:270:71: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:271:26: C0326: Exactly one space required after comma
#         if ced not in {'e','d'}:
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:274:63: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:275:30: C0326: Exactly one space required after comma
#             if ctf not in {'t','f'}:
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:286:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:290:26: C0326: Exactly one space required after comma
#         if cyn not in {'y','n'}:
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:301:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:303:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:305:102: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:305:0: C0301: Line too long (102/100) (line-too-long)
# caesar_cmd.py:311:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:314:90: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:315:91: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:316:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:318:126: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:318:0: C0301: Line too long (126/100) (line-too-long)
# caesar_cmd.py:319:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:320:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:322:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:323:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:329:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:338:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:339:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:348:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:350:15: C0326: Exactly one space required before comparison
#     if args.k  != 'x':
#
#                ^^ (bad-whitespace)
# caesar_cmd.py:357:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:359:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:365:17: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                  ^ (bad-whitespace)
# caesar_cmd.py:365:26: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                           ^ (bad-whitespace)
# caesar_cmd.py:365:35: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                                    ^ (bad-whitespace)
# caesar_cmd.py:365:45: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                                              ^ (bad-whitespace)
# caesar_cmd.py:365:55: C0326: Exactly one space required after comma
# def main(ced=None,ctf=None,cyn=None,text=None,file=None,key=False):
#
#                                                        ^ (bad-whitespace)
# caesar_cmd.py:366:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:368:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:369:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:371:0: C0301: Line too long (117/100) (line-too-long)
# caesar_cmd.py:371:116: C0326: No space allowed before bracket
#     print('Welcome to extended caesar cipher. This utility encrypts text or file using caesar cipher\'s principle.' )
#
#                                                                                                                     ^ (bad-whitespace)
# caesar_cmd.py:379:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:381:52: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:383:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:385:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:387:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:393:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:394:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:395:40: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:395:19: C0326: Exactly one space required after comparison
#             if cyn =='x':      # cmdline
#
#                    ^^ (bad-whitespace)
# caesar_cmd.py:396:72: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:400:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,99999))
#
#                                                                              ^ (bad-whitespace)
# caesar_cmd.py:401:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:402:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:406:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:408:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:409:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:413:49: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:416:77: C0326: Exactly one space required after comma
#                 dict_keys, original_key, new_key = e.get_key(en_key=randint(1,sys.maxunicode))
#
#                                                                              ^ (bad-whitespace)
# caesar_cmd.py:417:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:419:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:422:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:424:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:426:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:428:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:430:31: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:432:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:434:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:437:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:439:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:440:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:444:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:446:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:449:57: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:452:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:460:4: C0326: No space allowed before :
# try :
#
#     ^ (bad-whitespace)
# caesar_cmd.py:461:47: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:464:5: C0326: No space allowed before :
# else :
#
#      ^ (bad-whitespace)
# caesar_cmd.py:470:8: C0326: No space allowed before :
# finally :
#
#         ^ (bad-whitespace)
# caesar_cmd.py:471:30: C0326: No space allowed before :
#     if __name__ == "__main__" :
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:476:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:479:20: C0326: Exactly one space required after assignment
#                 ced ='e'
#
#                     ^ (bad-whitespace)
# caesar_cmd.py:481:20: C0326: Exactly one space required after assignment
#                 ced ='d'
#
#                     ^ (bad-whitespace)
# caesar_cmd.py:482:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:488:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:492:18: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:494:21: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:495:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:496:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:497:16: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                 ^ (bad-whitespace)
# caesar_cmd.py:497:20: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                     ^ (bad-whitespace)
# caesar_cmd.py:497:24: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                         ^ (bad-whitespace)
# caesar_cmd.py:497:30: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                               ^ (bad-whitespace)
# caesar_cmd.py:497:36: C0326: Exactly one space required after comma
#         main(ced,ctf,cyn,cmd.t,cmd.f,cmd.k)
#
#                                     ^ (bad-whitespace)
# caesar_cmd.py:498:0: C0303: Trailing whitespace (trailing-whitespace)
# caesar_cmd.py:511:0: C0305: Trailing newlines (trailing-newlines)
# caesar_cmd.py:377:14: W1401: Anomalous backslash in string: '\_'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# caesar_cmd.py:48:0: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:57:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cmd.py:61:8: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar_cmd.py:59:29: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:91:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:111:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:114:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:118:23: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cmd.py:130:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:158:53: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:190:57: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:196:16: W0101: Unreachable code (unreachable)
# caesar_cmd.py:204:8: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:210:19: C0121: Comparison to False should be 'not expr' (singleton-comparison)
# caesar_cmd.py:214:19: C0123: Using type() instead of isinstance() for a typecheck. (unidiomatic-typecheck)
# caesar_cmd.py:226:12: C0103: Variable name "DICT_KEYS" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:257:54: C0103: Variable name "f" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:270:8: W0621: Redefining name 'ced' from outer scope (line 479) (redefined-outer-name)
# caesar_cmd.py:274:12: W0621: Redefining name 'ctf' from outer scope (line 485) (redefined-outer-name)
# caesar_cmd.py:289:8: W0621: Redefining name 'cyn' from outer scope (line 494) (redefined-outer-name)
# caesar_cmd.py:299:0: C0116: Missing function or method docstring (missing-function-docstring)
# caesar_cmd.py:331:7: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar_cmd.py:331:25: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar_cmd.py:332:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:332:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:341:7: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar_cmd.py:341:25: C0121: Comparison to True should be just 'expr' (singleton-comparison)
# caesar_cmd.py:342:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:342:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:351:11: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:351:30: C0121: Comparison to True should be just 'not expr' (singleton-comparison)
# caesar_cmd.py:354:11: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:354:30: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:365:9: W0621: Redefining name 'ced' from outer scope (line 479) (redefined-outer-name)
# caesar_cmd.py:365:18: W0621: Redefining name 'ctf' from outer scope (line 485) (redefined-outer-name)
# caesar_cmd.py:365:27: W0621: Redefining name 'cyn' from outer scope (line 494) (redefined-outer-name)
# caesar_cmd.py:403:12: W0621: Redefining name 'result' from outer scope (line 48) (redefined-outer-name)
# caesar_cmd.py:365:0: R0913: Too many arguments (6/5) (too-many-arguments)
# caesar_cmd.py:381:7: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:381:23: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:381:23: E0602: Undefined variable 'cft' (undefined-variable)
# caesar_cmd.py:386:8: C0103: Variable name "e" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:389:15: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:391:15: C0121: Comparison to None should be 'expr is None' (singleton-comparison)
# caesar_cmd.py:427:8: C0103: Variable name "d" doesn't conform to snake_case naming style (invalid-name)
# caesar_cmd.py:365:0: R0912: Too many branches (14/12) (too-many-branches)
# caesar_cmd.py:365:0: R0915: Too many statements (59/50) (too-many-statements)
# caesar_cmd.py:462:7: W0703: Catching too general exception Exception (broad-except)
# caesar_cmd.py:461:4: C0103: Constant name "terminal" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:461:15: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:465:7: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:466:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:467:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:468:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:469:8: E0602: Undefined variable 'get_ipython' (undefined-variable)
# caesar_cmd.py:472:8: C0103: Constant name "cmd" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:479:16: C0103: Constant name "ced" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:481:16: C0103: Constant name "ced" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:484:15: C0121: Comparison to None should be 'expr is not None' (singleton-comparison)
# caesar_cmd.py:485:16: C0103: Constant name "ctf" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:487:16: C0103: Constant name "ctf" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:494:12: C0103: Constant name "cyn" doesn't conform to UPPER_CASE naming style (invalid-name)
# caesar_cmd.py:31:0: C0411: standard import "import argparse" should be placed before "import chardet" (wrong-import-order)
# caesar_cmd.py:32:0: C0411: standard import "import sys" should be placed before "import chardet" (wrong-import-order)
# caesar_cmd.py:33:0: C0411: standard import "from os import path" should be placed before "import chardet" (wrong-import-order)
# caesar_cmd.py:34:0: C0411: standard import "from random import randint" should be placed before "import chardet" (wrong-import-order)
#
# --------------------------------------------------------------------
#
# Your code has been rated at -2.47/10 (previous run: -2.47/10, +0.00)
#
#
#
# Namespace(d=False, e=False, f='C:\\Users\\tcs1128747\\AppData\\Roaming\\jupyter\\runtime\\kernel-4f19ad27-cc4d-4b9d-bf5c-e467ae14fc7a.json', i=False, k='x', t=None)
# usage: ipykernel_launcher.py [-h] [-i] [-t T | -f F] [-e | -d] [-k [K]]
# ipykernel_launcher.py: error: usage: caesar [-e|-d]  [-t|-f] <TEXT>/<FILE_PATH>  -k <INT>/<EMPTY>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\tcs1128747\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
